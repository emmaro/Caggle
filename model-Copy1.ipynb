# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from catboost import Pool, CatBoostClassifier, cv
pd.options.display.max_columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Prep

# %%
X_train = pd.read_csv('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/train/X_train.csv', index_col='id')
y_train = pd.read_csv('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/train/y_train.csv', squeeze=True)
X_test = pd.read_csv ('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/test/X_test.csv')
y_test = np.full(len(X_test), np.nan)

# %%
df = pd.concat([X_train, X_test])

df = df.drop(['v_screening_date'], axis=1) # duplicate of 'screening_date'
df = df.drop(['v_type_of_assessment'], axis=1) # duplicate of 'type_of_assessment'
df = df.drop(['type_of_assessment'], axis=1) # 0 variance

df['target'] = y_train.to_list() + list(y_test) # set target row-wise (ignoring indices)
# df['target'] = 0

# %%
# Engineer a new targets 
df['target_int'] = df['target'].replace({'No-Recidivism': 0, 'Non-Violent': 1, 'Violent': 2}) # so we can do regression
df['target_bool'] = df['target'].replace({'No-Recidivism': 0, 'Non-Violent': 1, 'Violent': 1}) # 0 - no-rec, 1 - rec
target_cols = ['target', 'target_int', 'target_bool']

# %%
# Engineer new date based features

"""
Custody: when someone is kept in prison until they go to court
Screening:  involves  using  a  brief  instrument  to  quickly  capture basic information 
    about a person’s risk to reoffend and is  used  to  determine  if  a  more  comprehensive  assessment
    is  warranted.  In  a  jail  setting,  everyone,  regardless  of  legal  status, should be screened 
    at booking.  Risk  screening  divides  the  jail  population  into  high-,  medium-,  and  low-risk 
    categories,  making  it  possible  to  direct  intervention  resources  first  to  the highest-risk individuals.



- c_arrest_date and c_offense_date are mutually exclusive and one of them is 99.8% likely to be filled
- c_arrest_date and c_are mutually exclusive
- start is number of days between c_jail_in and c_jail_out, maybe worth engineering total hours/minutes between
- screening_date is always filled
"""



days_cols = []

def days_between(d1, d2):
    try:
        try:
            d1 = datetime.strptime(d1, "%Y-%m-%d")
        except ValueError:
            d1 = datetime.strptime(d1, "%Y-%m-%d %H:%M:%S")
            
        try:
            d2 = datetime.strptime(d2, "%Y-%m-%d")
        except ValueError:
            d2 = datetime.strptime(d2, "%Y-%m-%d %H:%M:%S")
        return (d2 - d1).days
    except TypeError as e:
        return None

# mutually exclusive and one of them is always filled
df['c_bad_date'] = df['c_arrest_date'].fillna(df['c_offense_date']).fillna(df['in_custody']).fillna(df['screening_date'])

# how many days in custody
df['custody_days'] = df.apply(lambda x: days_between(x.out_custody, x.in_custody), axis=1)

# how quickly after going into custody did the person get screened (might indicate something?)
df['in_custody_to_screening_days'] = df.apply(lambda x: days_between(x.in_custody, x.screening_date), axis=1)

# questionable col because it is age related... Also corr=1 with age
df['birth_to_bad_days'] = df.apply(lambda x: days_between(x.date_of_birth, x.c_bad_date), axis=1)

# How many days passed until recitivism occcured. Golden feature!
df['days_until_recitivism'] = df.apply(lambda x: days_between(x.c_jail_out, x.r_jail_in), axis=1)

date_cols = [ 
    'c_arrest_date', 
    'c_offense_date',
    'screening_date', 
    'in_custody', 
    'out_custody', 
    'date_of_birth',
    'c_jail_in',
    'c_jail_out',
    'r_jail_in',
    'r_jail_out',

    # engineered
    'c_bad_date'
]

duration_cols = [
    'days_b_screening_arrest',
    'custody_days',
    'in_custody_to_screening_days',
    'birth_to_bad_days',
    'days_until_recitivism',
]

df.head()
# Out:
#                      name     first        last     sex date_of_birth  age  \
# 2677  nicholas staggewise  nicholas  staggewise    Male    1994-02-28   22
# 548          newton smith    newton       smith    Male    1995-01-28   21
# 4483       terrance irvin  terrance       irvin    Male    1984-04-10   32
# 9476      jaimie peterson    jaimie    peterson  Female    1986-01-02   30
# 199       ritesh sukhlall    ritesh    sukhlall    Male    1987-05-12   28
#
#          age_group              race  juv_fel_count  juv_misd_count  \
# 2677  Less than 25         Caucasian              0               0
# 548   Less than 25  African-American              0               1
# 4483       25 - 45  African-American              0               0
# 9476       25 - 45  African-American              0               0
# 199        25 - 45         Caucasian              0               0
#
#       juv_other_count  priors_count  days_b_screening_arrest  \
# 2677                0             2                     -1.0
# 548                 0             1                     -1.0
# 4483                0             6                     -1.0
# 9476                0             3                     -1.0
# 199                 0             2                      NaN
#
#                 c_jail_in           c_jail_out c_offense_date c_arrest_date  \
# 2677  2013-09-23 09:01:58  2013-09-27 03:54:42            NaN    2013-09-23
# 548   2013-06-16 12:36:42  2013-06-16 07:01:42     2013-06-15           NaN
# 4483  2013-10-11 05:38:14  2013-10-15 07:11:17     2013-10-11           NaN
# 9476  2014-01-11 06:56:43  2014-01-12 02:17:00     2014-01-11           NaN
# 199                   NaN                  NaN            NaN    2013-03-21
#
#      c_charge_degree                   c_charge_desc   r_jail_in  r_jail_out  \
# 2677               F           arrest case no charge         NaN         NaN
# 548                F   Grand Theft in the 3rd Degree         NaN         NaN
# 4483               F   Grand Theft in the 3rd Degree  2013-12-21  2014-02-21
# 9476               F  Felony Driving While Lic Suspd         NaN         NaN
# 199                F           arrest case no charge         NaN         NaN
#
#      screening_date  in_custody out_custody  start  id         target  \
# 2677     2013-09-24  2013-09-23  2013-09-27      3 NaN  No-Recidivism
# 548      2013-06-17  2013-06-16  2013-06-16      0 NaN        Violent
# 4483     2013-10-12  2013-10-11  2013-10-15      3 NaN    Non-Violent
# 9476     2014-01-12  2014-01-11  2014-01-12      0 NaN  No-Recidivism
# 199      2013-08-29         NaN         NaN      0 NaN  No-Recidivism
#
#       target_int  target_bool  c_bad_date  custody_days  \
# 2677         0.0          0.0  2013-09-23          -4.0
# 548          2.0          1.0  2013-06-15           0.0
# 4483         1.0          1.0  2013-10-11          -4.0
# 9476         0.0          0.0  2014-01-11          -1.0
# 199          0.0          0.0  2013-03-21           NaN
#
#       in_custody_to_screening_days  birth_to_bad_days  days_until_recitivism
# 2677                           1.0               7147                    NaN
# 548                            1.0               6713                    NaN
# 4483                           1.0              10776                   66.0
# 9476                           1.0              10236                    NaN
# 199                            NaN               9445                    NaN

# %%
# All prior counts
df['all_priors'] = df[[
    'juv_fel_count',
    'juv_misd_count', 
    'juv_other_count',
    'priors_count',
]].sum(axis=1)

# %%
# Has recidivism occured?
df['has_r_jail_in'] = df['r_jail_in'].notna()
df['has_r_jail_out'] = df['r_jail_out'].notna()

# %%
# fill missing values
df['c_charge_desc'] = df['c_charge_desc'].fillna('missing')

# %%
df.head()
# Out:
#                      name     first        last     sex date_of_birth  age  \
# 2677  nicholas staggewise  nicholas  staggewise    Male    1994-02-28   22
# 548          newton smith    newton       smith    Male    1995-01-28   21
# 4483       terrance irvin  terrance       irvin    Male    1984-04-10   32
# 9476      jaimie peterson    jaimie    peterson  Female    1986-01-02   30
# 199       ritesh sukhlall    ritesh    sukhlall    Male    1987-05-12   28
#
#          age_group              race  juv_fel_count  juv_misd_count  \
# 2677  Less than 25         Caucasian              0               0
# 548   Less than 25  African-American              0               1
# 4483       25 - 45  African-American              0               0
# 9476       25 - 45  African-American              0               0
# 199        25 - 45         Caucasian              0               0
#
#       juv_other_count  priors_count  days_b_screening_arrest  \
# 2677                0             2                     -1.0
# 548                 0             1                     -1.0
# 4483                0             6                     -1.0
# 9476                0             3                     -1.0
# 199                 0             2                      NaN
#
#                 c_jail_in           c_jail_out c_offense_date c_arrest_date  \
# 2677  2013-09-23 09:01:58  2013-09-27 03:54:42            NaN    2013-09-23
# 548   2013-06-16 12:36:42  2013-06-16 07:01:42     2013-06-15           NaN
# 4483  2013-10-11 05:38:14  2013-10-15 07:11:17     2013-10-11           NaN
# 9476  2014-01-11 06:56:43  2014-01-12 02:17:00     2014-01-11           NaN
# 199                   NaN                  NaN            NaN    2013-03-21
#
#      c_charge_degree                   c_charge_desc   r_jail_in  r_jail_out  \
# 2677               F           arrest case no charge         NaN         NaN
# 548                F   Grand Theft in the 3rd Degree         NaN         NaN
# 4483               F   Grand Theft in the 3rd Degree  2013-12-21  2014-02-21
# 9476               F  Felony Driving While Lic Suspd         NaN         NaN
# 199                F           arrest case no charge         NaN         NaN
#
#      screening_date  in_custody out_custody  start  id         target  \
# 2677     2013-09-24  2013-09-23  2013-09-27      3 NaN  No-Recidivism
# 548      2013-06-17  2013-06-16  2013-06-16      0 NaN        Violent
# 4483     2013-10-12  2013-10-11  2013-10-15      3 NaN    Non-Violent
# 9476     2014-01-12  2014-01-11  2014-01-12      0 NaN  No-Recidivism
# 199      2013-08-29         NaN         NaN      0 NaN  No-Recidivism
#
#       target_int  target_bool  c_bad_date  custody_days  \
# 2677         0.0          0.0  2013-09-23          -4.0
# 548          2.0          1.0  2013-06-15           0.0
# 4483         1.0          1.0  2013-10-11          -4.0
# 9476         0.0          0.0  2014-01-11          -1.0
# 199          0.0          0.0  2013-03-21           NaN
#
#       in_custody_to_screening_days  birth_to_bad_days  days_until_recitivism  \
# 2677                           1.0               7147                    NaN
# 548                            1.0               6713                    NaN
# 4483                           1.0              10776                   66.0
# 9476                           1.0              10236                    NaN
# 199                            NaN               9445                    NaN
#
#       all_priors  has_r_jail_in  has_r_jail_out
# 2677           2          False           False
# 548            2          False           False
# 4483           6           True            True
# 9476           3          False           False
# 199            2          False           False

# %%
##########################################
### Select features to use in modeling ###
##########################################

cols = [
#     'name', useless
#     'first', useless
#     'last', useless
#     'sex', # 0 importance + potential bias
#     'date_of_birth', date
#     'age', # innapropriate bias
#     'age_group', # innapropriate bias
#     'race', # innapropriate bias
#     'juv_fel_count',
#     'juv_misd_count', 
#     'juv_other_count',
#     'priors_count', 
    'days_b_screening_arrest', # + AUC, - fairness
#     'c_jail_in', date
#     'c_jail_out',date
#     'c_offense_date', date
#     'c_arrest_date', date
#     'c_charge_degree',  # 0 importance
#     'c_charge_desc',
#     'r_jail_in', date
#     'r_jail_out', date
#     'screening_date', date
#     'in_custody', date
#     'out_custody', date
    'start', # + AUC, + fairness
#     'target', target
#     'target_int', target
#     'target_bool', target
#     'c_bad_date', date
    'custody_days', # + AOC, + fairness
    'in_custody_to_screening_days', # + AUC, + fairness
#     'birth_to_bad_days', # corr=1 with age
#     'has_r_jail_in', + AUC, - fairness
#     'has_r_jail_out', # corr=1 with r_jail_in
    'days_until_recitivism', # golden feature!
    'all_priors', # good
]

cat_cols = [
#     'sex',  # innapropriate bias
#     'age_group', # innapropriate bias
#     'race', # innapropriate bias
#     'c_charge_degree', # 0 importance
#     'c_charge_desc',
]

# %%
# Count missing values
df[cols].isna().sum()/len(df[cols])
# Out:
# days_b_screening_arrest         0.056504
# start                           0.000000
# custody_days                    0.044065
# in_custody_to_screening_days    0.044065
# days_until_recitivism           0.855577
# all_priors                      0.000000
# dtype: float64

# %%
# Numeric correlations across numeric features
f, ax = plt.subplots(figsize=(16, 12))
corr = df[cols].corr()
mask = np.triu(corr)
sns.heatmap(corr.select_dtypes('number'), annot=True, center=0, mask=mask)
# Out:
# <AxesSubplot:>

# %%
df[cols].head()
# Out:
#       days_b_screening_arrest  start  custody_days  \
# 2677                     -1.0      3          -4.0
# 548                      -1.0      0           0.0
# 4483                     -1.0      3          -4.0
# 9476                     -1.0      0          -1.0
# 199                       NaN      0           NaN
#
#       in_custody_to_screening_days  days_until_recitivism  all_priors
# 2677                           1.0                    NaN           2
# 548                            1.0                    NaN           2
# 4483                           1.0                   66.0           6
# 9476                           1.0                    NaN           3
# 199                            NaN                    NaN           2

# %%
# df['race'] = df['race'].replace({'Native American': 'Other'})
# df['race'] = df['race'].replace({'Native American': 'Other', 'Asian': 'Other'})
df['race'] = df['race'].replace({'Native American': 'Other', 'Asian': 'Other', 'Hispanic': 'Other'})
df['race'].value_counts()
# Out:
# African-American    2266
# Caucasian           1701
# Other                776
# Name: race, dtype: int64

# %%
races = df.race.unique()
sexes = df.sex.unique()
age_groups = df.age_group.unique()

df.shape
# Out:
# (4743, 37)

# %% [markdown]
# # Cross Validation

# %%
df[cols] = df[cols].fillna(0)

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score

def fairness_score(y_true, y_pred, sensitive_features):
    mf = MetricFrame(roc_auc_score, y_true, y_pred, sensitive_features=sensitive_features)
    return (1 - np.sqrt(np.std(mf.by_group)))

# %%
df_train = df[df.target.notna()]

df_test = df[df.target.isna()]

# %% [markdown]
# # Multi-class Classification
# Non-recidivism / Non-Violent / Violent

# %%
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
import collections
from fairlearn.metrics import MetricFrame

TARGET_COL = 'target'

N_SPLITS = 5
N_REPEATS = 10

# Stratify based on intersections of race, age_group, sex and target.
strat_df = pd.DataFrame(df_train[TARGET_COL].astype('str') + df_train['race'] + df_train['sex'] + df_train['age_group'], columns=['name'])

# If cross section is too small for stratification to work (N < N_SPLITS) we mark it as an outlier
strat_df.loc[strat_df.groupby('name').name.transform('count').lt(N_SPLITS), 'name'] = 'Outliers'    

kf = RepeatedStratifiedKFold(n_splits=N_SPLITS, n_repeats=N_REPEATS, random_state=42)

roc_aucs = []
rms = []
sms = []
ams = []

feature_importances = []
for split_idx, (train, test) in enumerate(kf.split(df_train[cols], strat_df['name'])): # Stratified on race
    df_train_cv = df.iloc[train].reset_index(drop=True)
    df_eval_cv = df.iloc[test].reset_index(drop=True)
    
    train_dataset = Pool(data=df_train_cv[cols],
                         label=df_train_cv[TARGET_COL],
                         cat_features=cat_cols)

    eval_dataset = Pool(data=df_eval_cv[cols],
                        label=df_eval_cv[TARGET_COL],
                        cat_features=cat_cols)
    
    y_eval = pd.get_dummies(df_eval_cv[TARGET_COL]).to_numpy()
    # Initialize CatBoostClassifier
    model = CatBoostClassifier(iterations=1000,
                               learning_rate=1,
                               depth=3,
                               loss_function='MultiClass')
    # Fit model
    model.fit(train_dataset, verbose=False)
#     # Get predicted probabilities for each class
    preds_proba = model.predict_proba(eval_dataset)
    
    roc_auc = roc_auc_score(y_eval, preds_proba, multi_class="ovo")
    rm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['race'])
    sm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['sex'])
    am = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['age_group'])
    
    roc_aucs.append(roc_auc)
    rms.append(rm)
    sms.append(sm)
    ams.append(am)
        
    roc_aucs.append(roc_auc)
    feature_importances.append(model.get_feature_importance())
    # avg_precs.append(avg_prec)
    race_fairness = 1 - np.sqrt(np.std(rm.by_group))
    sex_fairness = 1 - np.sqrt(np.std(sm.by_group))
    age_fairness = 1 - np.sqrt(np.std(am.by_group))
    print(f'Split {split_idx+1:2}: ROC-AUC: {roc_auc*100:.2f}%. '
          f'Fairness: R: {race_fairness*100:.2f}%, S: {sex_fairness*100:.2f}%, A: {age_fairness*100:.2f}%')
# Out:
# Split  1: ROC-AUC: 82.02%. Fairness: R: 86.04%, S: 73.90%, A: 77.09%
# Split  2: ROC-AUC: 85.57%. Fairness: R: 80.96%, S: 86.31%, A: 73.67%
# Split  3: ROC-AUC: 84.93%. Fairness: R: 77.43%, S: 98.36%, A: 88.09%
# Split  4: ROC-AUC: 86.53%. Fairness: R: 80.27%, S: 81.91%, A: 82.43%
# Split  5: ROC-AUC: 87.56%. Fairness: R: 84.04%, S: 81.69%, A: 78.32%
# Split  6: ROC-AUC: 82.75%. Fairness: R: 84.88%, S: 83.28%, A: 84.23%
# Split  7: ROC-AUC: 84.74%. Fairness: R: 90.76%, S: 90.20%, A: 82.84%
# Split  8: ROC-AUC: 84.17%. Fairness: R: 79.47%, S: 98.36%, A: 87.36%
# Split  9: ROC-AUC: 90.14%. Fairness: R: 83.98%, S: 79.59%, A: 75.89%
# Split 10: ROC-AUC: 84.81%. Fairness: R: 71.66%, S: 85.54%, A: 72.81%
# Split 11: ROC-AUC: 82.68%. Fairness: R: 80.76%, S: 90.44%, A: 84.02%
# Split 12: ROC-AUC: 80.11%. Fairness: R: 75.25%, S: 81.83%, A: 68.30%
# Split 13: ROC-AUC: 89.33%. Fairness: R: 85.03%, S: 91.16%, A: 86.87%
# Split 14: ROC-AUC: 84.03%. Fairness: R: 84.53%, S: 77.85%, A: 80.55%
# Split 15: ROC-AUC: 84.51%. Fairness: R: 82.67%, S: 90.10%, A: 77.94%
# Split 16: ROC-AUC: 85.53%. Fairness: R: 75.77%, S: 93.88%, A: 78.22%
# Split 17: ROC-AUC: 83.07%. Fairness: R: 87.45%, S: 95.70%, A: 81.61%
# Split 18: ROC-AUC: 85.19%. Fairness: R: 76.05%, S: 92.71%, A: 81.27%
# Split 19: ROC-AUC: 82.08%. Fairness: R: 82.52%, S: 77.11%, A: 86.60%
# Split 20: ROC-AUC: 88.85%. Fairness: R: 77.71%, S: 79.79%, A: 79.99%
# Split 21: ROC-AUC: 84.97%. Fairness: R: 79.12%, S: 90.33%, A: 80.10%
# Split 22: ROC-AUC: 81.64%. Fairness: R: 87.67%, S: 86.05%, A: 77.65%
# Split 23: ROC-AUC: 84.76%. Fairness: R: 85.27%, S: 73.52%, A: 82.68%
# Split 24: ROC-AUC: 83.84%. Fairness: R: 80.73%, S: 91.27%, A: 75.46%
# Split 25: ROC-AUC: 83.74%. Fairness: R: 82.37%, S: 86.95%, A: 79.96%
# Split 26: ROC-AUC: 89.14%. Fairness: R: 88.16%, S: 79.51%, A: 82.51%
# Split 27: ROC-AUC: 81.47%. Fairness: R: 68.53%, S: 91.78%, A: 86.31%
# Split 28: ROC-AUC: 87.07%. Fairness: R: 78.18%, S: 76.73%, A: 74.60%
# Split 29: ROC-AUC: 84.25%. Fairness: R: 81.61%, S: 91.60%, A: 78.61%
# Split 30: ROC-AUC: 84.70%. Fairness: R: 88.68%, S: 85.74%, A: 82.49%
# Split 31: ROC-AUC: 85.84%. Fairness: R: 81.26%, S: 76.31%, A: 72.22%
# Split 32: ROC-AUC: 83.56%. Fairness: R: 83.88%, S: 88.18%, A: 85.00%
# Split 33: ROC-AUC: 86.84%. Fairness: R: 88.01%, S: 89.57%, A: 84.05%
# Split 34: ROC-AUC: 79.88%. Fairness: R: 83.00%, S: 84.86%, A: 77.40%
# Split 35: ROC-AUC: 87.25%. Fairness: R: 79.45%, S: 91.49%, A: 87.76%
# Split 36: ROC-AUC: 83.50%. Fairness: R: 83.19%, S: 73.65%, A: 72.29%
# Split 37: ROC-AUC: 83.01%. Fairness: R: 83.43%, S: 91.45%, A: 84.23%
# Split 38: ROC-AUC: 85.61%. Fairness: R: 90.25%, S: 83.25%, A: 78.18%
# Split 39: ROC-AUC: 84.62%. Fairness: R: 90.00%, S: 97.14%, A: 79.67%
# Split 40: ROC-AUC: 83.90%. Fairness: R: 85.28%, S: 89.76%, A: 86.98%
# Split 41: ROC-AUC: 87.08%. Fairness: R: 85.27%, S: 89.81%, A: 83.25%
# Split 42: ROC-AUC: 86.72%. Fairness: R: 68.76%, S: 95.31%, A: 79.26%
# Split 43: ROC-AUC: 85.69%. Fairness: R: 80.40%, S: 85.37%, A: 77.69%
# Split 44: ROC-AUC: 82.25%. Fairness: R: 82.59%, S: 75.91%, A: 81.86%
# Split 45: ROC-AUC: 81.87%. Fairness: R: 84.96%, S: 79.95%, A: 81.11%
# Split 46: ROC-AUC: 87.27%. Fairness: R: 86.59%, S: 91.30%, A: 86.20%
# Split 47: ROC-AUC: 82.67%. Fairness: R: 85.38%, S: 80.25%, A: 75.40%
# Split 48: ROC-AUC: 83.96%. Fairness: R: 92.87%, S: 87.33%, A: 78.31%
# Split 49: ROC-AUC: 88.73%. Fairness: R: 83.04%, S: 84.86%, A: 86.21%
# Split 50: ROC-AUC: 86.02%. Fairness: R: 83.03%, S: 75.09%, A: 79.15%

# %%
# Evaluation

race_fairnesses = [(1 - np.sqrt(np.std(rm.by_group))) for rm in rms]
sex_fairnesses = [(1 - np.sqrt(np.std(sm.by_group))) for sm in sms]
age_fairnesses = [(1 - np.sqrt(np.std(am.by_group))) for am in ams]

print(f'ROC-AUC {np.mean(roc_aucs)*100:.2f}% (STD: {np.std(roc_aucs)*100:.2f}%)') # 90.48
print(f'Race fairness: {np.mean(race_fairnesses)*100:.2f}% (STD: {np.std(race_fairnesses)*100:.2f}%)') # 83.92
print(f'Sex fairness: {np.mean(sex_fairnesses)*100:.2f}% (STD: {np.std(sex_fairnesses)*100:.2f}%)')
print(f'Age fairness: {np.mean(age_fairnesses)*100:.2f}% (STD: {np.std(age_fairnesses)*100:.2f}%)')

score = 0.5 * np.mean(roc_aucs) + \
        0.5 * (np.mean([np.mean(race_fairnesses), np.mean(sex_fairnesses), np.mean(age_fairnesses)]))
print(f'Score: {score*100:.2f}%') # 90.48
# Out:
# ROC-AUC 84.81% (STD: 2.33%)
# Race fairness: 82.56% (STD: 5.09%)
# Sex fairness: 85.88% (STD: 6.80%)
# Age fairness: 80.49% (STD: 4.59%)
# Score: 83.89%

# %%
race_auc_df = pd.DataFrame({'race': races, 'auc': rm.by_group})
sex_auc_df = pd.DataFrame({'sex': sexes, 'auc': sm.by_group})
age_auc_df = pd.DataFrame({'age': age_groups, 'auc': am.by_group})
                     
display(race_auc_df[race_auc_df['auc'].notna()].plot.barh(x='race'))
display(sex_auc_df[sex_auc_df['auc'].notna()].plot.barh(x='sex'))
display(age_auc_df[age_auc_df['auc'].notna()].plot.barh(x='age'))
# Out:
# <AxesSubplot:ylabel='race'>
# <AxesSubplot:ylabel='sex'>
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# # Full model

# %%
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
import collections
from fairlearn.metrics import MetricFrame

TARGET_COL = 'target'

train_dataset = Pool(data=df_train[cols],
                     label=df_train[TARGET_COL],
                     cat_features=cat_cols)

eval_dataset = Pool(data=df_test[cols],
                    label=None,
                    cat_features=cat_cols)

# y_eval = pd.get_dummies(eval_df[TARGET_COL]).to_numpy()
# Initialize CatBoostClassifier
model = CatBoostClassifier(iterations=1000,
                           learning_rate=1,
                           depth=2,
                           loss_function='MultiClass')
# Fit model
model.fit(train_dataset, verbose=True)
# Get predicted classes
preds_class = model.predict(eval_dataset)
#     # Get predicted probabilities for each class
preds_proba = model.predict_proba(eval_dataset)
#     # Get predicted RawFormulaVal
#     preds_raw = model.predict(eval_dataset, 
#                               prediction_type='RawFormulaVal')

feature_importances.append(model.get_feature_importance())
# Out:
# 0:	learn: 0.3703039	total: 9.17ms	remaining: 9.16s
# 1:	learn: 0.3130068	total: 10.9ms	remaining: 5.45s
# 2:	learn: 0.2911159	total: 12.5ms	remaining: 4.17s
# 3:	learn: 0.2837932	total: 14ms	remaining: 3.48s
# 4:	learn: 0.2794900	total: 15.5ms	remaining: 3.07s
# 5:	learn: 0.2764436	total: 17.1ms	remaining: 2.82s
# 6:	learn: 0.2740210	total: 18.5ms	remaining: 2.62s
# 7:	learn: 0.2715119	total: 20.3ms	remaining: 2.51s
# 8:	learn: 0.2703327	total: 22ms	remaining: 2.42s
# 9:	learn: 0.2693255	total: 23.3ms	remaining: 2.31s
# 10:	learn: 0.2678919	total: 24.9ms	remaining: 2.24s
# 11:	learn: 0.2669980	total: 26.4ms	remaining: 2.17s
# 12:	learn: 0.2662257	total: 28ms	remaining: 2.12s
# 13:	learn: 0.2634589	total: 29.7ms	remaining: 2.09s
# 14:	learn: 0.2608290	total: 31ms	remaining: 2.04s
# 15:	learn: 0.2603635	total: 32.4ms	remaining: 2s
# 16:	learn: 0.2586019	total: 33.8ms	remaining: 1.95s
# 17:	learn: 0.2580890	total: 35.2ms	remaining: 1.92s
# 18:	learn: 0.2577054	total: 36.6ms	remaining: 1.89s
# 19:	learn: 0.2562156	total: 38ms	remaining: 1.86s
# 20:	learn: 0.2551074	total: 39.5ms	remaining: 1.84s
# 21:	learn: 0.2546127	total: 41.1ms	remaining: 1.82s
# 22:	learn: 0.2534573	total: 42.5ms	remaining: 1.8s
# 23:	learn: 0.2530503	total: 44.1ms	remaining: 1.79s
# 24:	learn: 0.2511158	total: 45.5ms	remaining: 1.77s
# 25:	learn: 0.2506715	total: 46.9ms	remaining: 1.76s
# 26:	learn: 0.2503999	total: 48.1ms	remaining: 1.73s
# 27:	learn: 0.2502698	total: 49.7ms	remaining: 1.72s
# 28:	learn: 0.2501451	total: 51ms	remaining: 1.71s
# 29:	learn: 0.2494923	total: 52.3ms	remaining: 1.69s
# 30:	learn: 0.2487666	total: 53.7ms	remaining: 1.68s
# 31:	learn: 0.2477049	total: 55ms	remaining: 1.66s
# 32:	learn: 0.2468808	total: 56.4ms	remaining: 1.65s
# 33:	learn: 0.2466625	total: 58.1ms	remaining: 1.65s
# 34:	learn: 0.2460315	total: 60.1ms	remaining: 1.66s
# 35:	learn: 0.2457006	total: 61.5ms	remaining: 1.65s
# 36:	learn: 0.2450363	total: 63.2ms	remaining: 1.65s
# 37:	learn: 0.2442266	total: 64.8ms	remaining: 1.64s
# 38:	learn: 0.2440058	total: 66.2ms	remaining: 1.63s
# 39:	learn: 0.2439418	total: 67.7ms	remaining: 1.62s
# 40:	learn: 0.2434680	total: 69.1ms	remaining: 1.62s
# 41:	learn: 0.2431870	total: 70.8ms	remaining: 1.61s
# 42:	learn: 0.2427772	total: 72.2ms	remaining: 1.61s
# 43:	learn: 0.2422769	total: 73.8ms	remaining: 1.6s
# 44:	learn: 0.2410428	total: 75.1ms	remaining: 1.59s
# 45:	learn: 0.2408536	total: 76.5ms	remaining: 1.59s
# 46:	learn: 0.2405019	total: 77.9ms	remaining: 1.58s
# 47:	learn: 0.2400857	total: 79.3ms	remaining: 1.57s
# 48:	learn: 0.2398677	total: 80.8ms	remaining: 1.57s
# 49:	learn: 0.2395771	total: 82.2ms	remaining: 1.56s
# 50:	learn: 0.2394707	total: 83.5ms	remaining: 1.55s
# 51:	learn: 0.2394261	total: 84.8ms	remaining: 1.54s
# 52:	learn: 0.2390655	total: 86.2ms	remaining: 1.54s
# 53:	learn: 0.2384494	total: 87.5ms	remaining: 1.53s
# 54:	learn: 0.2379423	total: 88.9ms	remaining: 1.53s
# 55:	learn: 0.2374411	total: 90.4ms	remaining: 1.52s
# 56:	learn: 0.2372786	total: 91.7ms	remaining: 1.52s
# 57:	learn: 0.2370060	total: 93.1ms	remaining: 1.51s
# 58:	learn: 0.2364694	total: 94.9ms	remaining: 1.51s
# 59:	learn: 0.2360774	total: 96.8ms	remaining: 1.52s
# 60:	learn: 0.2354542	total: 98.2ms	remaining: 1.51s
# 61:	learn: 0.2353642	total: 99.7ms	remaining: 1.51s
# 62:	learn: 0.2353043	total: 101ms	remaining: 1.51s
# 63:	learn: 0.2352386	total: 103ms	remaining: 1.5s
# 64:	learn: 0.2347941	total: 104ms	remaining: 1.5s
# 65:	learn: 0.2346813	total: 105ms	remaining: 1.49s
# 66:	learn: 0.2345953	total: 107ms	remaining: 1.49s
# 67:	learn: 0.2340406	total: 108ms	remaining: 1.49s
# 68:	learn: 0.2338655	total: 110ms	remaining: 1.48s
# 69:	learn: 0.2337695	total: 111ms	remaining: 1.48s
# 70:	learn: 0.2337557	total: 113ms	remaining: 1.48s
# 71:	learn: 0.2336746	total: 115ms	remaining: 1.48s
# 72:	learn: 0.2333961	total: 116ms	remaining: 1.48s
# 73:	learn: 0.2329739	total: 118ms	remaining: 1.47s
# 74:	learn: 0.2327215	total: 119ms	remaining: 1.47s
# 75:	learn: 0.2324076	total: 120ms	remaining: 1.46s
# 76:	learn: 0.2317769	total: 122ms	remaining: 1.46s
# 77:	learn: 0.2304652	total: 123ms	remaining: 1.46s
# 78:	learn: 0.2303634	total: 125ms	remaining: 1.45s
# 79:	learn: 0.2301970	total: 126ms	remaining: 1.45s
# 80:	learn: 0.2291852	total: 128ms	remaining: 1.45s
# 81:	learn: 0.2290992	total: 129ms	remaining: 1.45s
# 82:	learn: 0.2283548	total: 131ms	remaining: 1.44s
# 83:	learn: 0.2280461	total: 133ms	remaining: 1.44s
# 84:	learn: 0.2280072	total: 134ms	remaining: 1.44s
# 85:	learn: 0.2277486	total: 135ms	remaining: 1.44s
# 86:	learn: 0.2274425	total: 137ms	remaining: 1.44s
# 87:	learn: 0.2273173	total: 138ms	remaining: 1.43s
# 88:	learn: 0.2272958	total: 140ms	remaining: 1.43s
# 89:	learn: 0.2271969	total: 141ms	remaining: 1.43s
# 90:	learn: 0.2266040	total: 142ms	remaining: 1.42s
# 91:	learn: 0.2257466	total: 144ms	remaining: 1.42s
# 92:	learn: 0.2254276	total: 145ms	remaining: 1.41s
# 93:	learn: 0.2252015	total: 146ms	remaining: 1.41s
# 94:	learn: 0.2249676	total: 148ms	remaining: 1.41s
# 95:	learn: 0.2247249	total: 149ms	remaining: 1.41s
# 96:	learn: 0.2246484	total: 151ms	remaining: 1.41s
# 97:	learn: 0.2244569	total: 153ms	remaining: 1.4s
# 98:	learn: 0.2242746	total: 154ms	remaining: 1.4s
# 99:	learn: 0.2239607	total: 156ms	remaining: 1.4s
# 100:	learn: 0.2234633	total: 157ms	remaining: 1.4s
# 101:	learn: 0.2229864	total: 159ms	remaining: 1.4s
# 102:	learn: 0.2229126	total: 160ms	remaining: 1.39s
# 103:	learn: 0.2226816	total: 161ms	remaining: 1.39s
# 104:	learn: 0.2225514	total: 163ms	remaining: 1.39s
# 105:	learn: 0.2224469	total: 164ms	remaining: 1.39s
# 106:	learn: 0.2223909	total: 166ms	remaining: 1.38s
# 107:	learn: 0.2223197	total: 167ms	remaining: 1.38s
# 108:	learn: 0.2221608	total: 169ms	remaining: 1.38s
# 109:	learn: 0.2217350	total: 170ms	remaining: 1.38s
# 110:	learn: 0.2214036	total: 172ms	remaining: 1.38s
# 111:	learn: 0.2212661	total: 174ms	remaining: 1.38s
# 112:	learn: 0.2210258	total: 175ms	remaining: 1.37s
# 113:	learn: 0.2207966	total: 177ms	remaining: 1.37s
# 114:	learn: 0.2206441	total: 178ms	remaining: 1.37s
# 115:	learn: 0.2200588	total: 180ms	remaining: 1.37s
# 116:	learn: 0.2199502	total: 182ms	remaining: 1.37s
# 117:	learn: 0.2197935	total: 185ms	remaining: 1.38s
# 118:	learn: 0.2194899	total: 187ms	remaining: 1.38s
# 119:	learn: 0.2186992	total: 188ms	remaining: 1.38s
# 120:	learn: 0.2186053	total: 190ms	remaining: 1.38s
# 121:	learn: 0.2185224	total: 192ms	remaining: 1.38s
# 122:	learn: 0.2184487	total: 193ms	remaining: 1.38s
# 123:	learn: 0.2176417	total: 196ms	remaining: 1.38s
# 124:	learn: 0.2175304	total: 198ms	remaining: 1.38s
# 125:	learn: 0.2174269	total: 200ms	remaining: 1.39s
# 126:	learn: 0.2170634	total: 202ms	remaining: 1.39s
# 127:	learn: 0.2169827	total: 204ms	remaining: 1.39s
# 128:	learn: 0.2166989	total: 205ms	remaining: 1.39s
# 129:	learn: 0.2165538	total: 207ms	remaining: 1.39s
# 130:	learn: 0.2164234	total: 209ms	remaining: 1.38s
# 131:	learn: 0.2162218	total: 210ms	remaining: 1.38s
# 132:	learn: 0.2160662	total: 212ms	remaining: 1.38s
# 133:	learn: 0.2154691	total: 213ms	remaining: 1.38s
# 134:	learn: 0.2152477	total: 215ms	remaining: 1.38s
# 135:	learn: 0.2141071	total: 216ms	remaining: 1.37s
# 136:	learn: 0.2137610	total: 218ms	remaining: 1.37s
# 137:	learn: 0.2135819	total: 219ms	remaining: 1.37s
# 138:	learn: 0.2133383	total: 221ms	remaining: 1.37s
# 139:	learn: 0.2132168	total: 222ms	remaining: 1.36s
# 140:	learn: 0.2128730	total: 224ms	remaining: 1.36s
# 141:	learn: 0.2128418	total: 225ms	remaining: 1.36s
# 142:	learn: 0.2126965	total: 227ms	remaining: 1.36s
# 143:	learn: 0.2124183	total: 229ms	remaining: 1.36s
# 144:	learn: 0.2123865	total: 230ms	remaining: 1.36s
# 145:	learn: 0.2122929	total: 232ms	remaining: 1.36s
# 146:	learn: 0.2116992	total: 233ms	remaining: 1.35s
# 147:	learn: 0.2115909	total: 235ms	remaining: 1.35s
# 148:	learn: 0.2115174	total: 236ms	remaining: 1.35s
# 149:	learn: 0.2111558	total: 238ms	remaining: 1.35s
# 150:	learn: 0.2107527	total: 240ms	remaining: 1.35s
# 151:	learn: 0.2106035	total: 241ms	remaining: 1.34s
# 152:	learn: 0.2103928	total: 243ms	remaining: 1.34s
# 153:	learn: 0.2094929	total: 245ms	remaining: 1.34s
# 154:	learn: 0.2093530	total: 246ms	remaining: 1.34s
# 155:	learn: 0.2092673	total: 248ms	remaining: 1.34s
# 156:	learn: 0.2091737	total: 249ms	remaining: 1.34s
# 157:	learn: 0.2089671	total: 251ms	remaining: 1.34s
# 158:	learn: 0.2087714	total: 252ms	remaining: 1.33s
# 159:	learn: 0.2086369	total: 254ms	remaining: 1.33s
# 160:	learn: 0.2086256	total: 255ms	remaining: 1.33s
# 161:	learn: 0.2082170	total: 257ms	remaining: 1.33s
# 162:	learn: 0.2079995	total: 258ms	remaining: 1.32s
# 163:	learn: 0.2078865	total: 259ms	remaining: 1.32s
# 164:	learn: 0.2078198	total: 261ms	remaining: 1.32s
# 165:	learn: 0.2077614	total: 263ms	remaining: 1.32s
# 166:	learn: 0.2076983	total: 264ms	remaining: 1.32s
# 167:	learn: 0.2075713	total: 266ms	remaining: 1.32s
# 168:	learn: 0.2073701	total: 267ms	remaining: 1.31s
# 169:	learn: 0.2071399	total: 269ms	remaining: 1.31s
# 170:	learn: 0.2069804	total: 270ms	remaining: 1.31s
# 171:	learn: 0.2068023	total: 272ms	remaining: 1.31s
# 172:	learn: 0.2063913	total: 273ms	remaining: 1.3s
# 173:	learn: 0.2062574	total: 275ms	remaining: 1.3s
# 174:	learn: 0.2061634	total: 276ms	remaining: 1.3s
# 175:	learn: 0.2061272	total: 278ms	remaining: 1.3s
# 176:	learn: 0.2060955	total: 279ms	remaining: 1.3s
# 177:	learn: 0.2055813	total: 281ms	remaining: 1.3s
# 178:	learn: 0.2054671	total: 282ms	remaining: 1.29s
# 179:	learn: 0.2054581	total: 284ms	remaining: 1.29s
# 180:	learn: 0.2053054	total: 285ms	remaining: 1.29s
# 181:	learn: 0.2051881	total: 286ms	remaining: 1.29s
# 182:	learn: 0.2051150	total: 288ms	remaining: 1.28s
# 183:	learn: 0.2050740	total: 289ms	remaining: 1.28s
# 184:	learn: 0.2045865	total: 291ms	remaining: 1.28s
# 185:	learn: 0.2044001	total: 292ms	remaining: 1.28s
# 186:	learn: 0.2041400	total: 294ms	remaining: 1.28s
# 187:	learn: 0.2040152	total: 295ms	remaining: 1.27s
# 188:	learn: 0.2038247	total: 296ms	remaining: 1.27s
# 189:	learn: 0.2036416	total: 298ms	remaining: 1.27s
# 190:	learn: 0.2028701	total: 300ms	remaining: 1.27s
# 191:	learn: 0.2025336	total: 301ms	remaining: 1.27s
# 192:	learn: 0.2022956	total: 303ms	remaining: 1.27s
# 193:	learn: 0.2021572	total: 305ms	remaining: 1.26s
# 194:	learn: 0.2020313	total: 306ms	remaining: 1.26s
# 195:	learn: 0.2015037	total: 307ms	remaining: 1.26s
# 196:	learn: 0.2013056	total: 309ms	remaining: 1.26s
# 197:	learn: 0.2011832	total: 310ms	remaining: 1.26s
# 198:	learn: 0.2010644	total: 312ms	remaining: 1.25s
# 199:	learn: 0.2005828	total: 313ms	remaining: 1.25s
# 200:	learn: 0.2005244	total: 314ms	remaining: 1.25s
# 201:	learn: 0.2003872	total: 316ms	remaining: 1.25s
# 202:	learn: 0.2001946	total: 318ms	remaining: 1.25s
# 203:	learn: 0.1998848	total: 320ms	remaining: 1.25s
# 204:	learn: 0.1997434	total: 321ms	remaining: 1.24s
# 205:	learn: 0.1996689	total: 323ms	remaining: 1.24s
# 206:	learn: 0.1994555	total: 324ms	remaining: 1.24s
# 207:	learn: 0.1993976	total: 326ms	remaining: 1.24s
# 208:	learn: 0.1991291	total: 327ms	remaining: 1.24s
# 209:	learn: 0.1990217	total: 328ms	remaining: 1.24s
# 210:	learn: 0.1988066	total: 330ms	remaining: 1.24s
# 211:	learn: 0.1987432	total: 332ms	remaining: 1.23s
# 212:	learn: 0.1982645	total: 334ms	remaining: 1.23s
# 213:	learn: 0.1981565	total: 335ms	remaining: 1.23s
# 214:	learn: 0.1979071	total: 337ms	remaining: 1.23s
# 215:	learn: 0.1978069	total: 339ms	remaining: 1.23s
# 216:	learn: 0.1975659	total: 341ms	remaining: 1.23s
# 217:	learn: 0.1974479	total: 342ms	remaining: 1.23s
# 218:	learn: 0.1972939	total: 344ms	remaining: 1.23s
# 219:	learn: 0.1971418	total: 346ms	remaining: 1.23s
# 220:	learn: 0.1969358	total: 347ms	remaining: 1.22s
# 221:	learn: 0.1968051	total: 349ms	remaining: 1.22s
# 222:	learn: 0.1965670	total: 350ms	remaining: 1.22s
# 223:	learn: 0.1965152	total: 352ms	remaining: 1.22s
# 224:	learn: 0.1965001	total: 353ms	remaining: 1.22s
# 225:	learn: 0.1961835	total: 355ms	remaining: 1.22s
# 226:	learn: 0.1960150	total: 357ms	remaining: 1.22s
# 227:	learn: 0.1959064	total: 358ms	remaining: 1.21s
# 228:	learn: 0.1958084	total: 360ms	remaining: 1.21s
# 229:	learn: 0.1957459	total: 362ms	remaining: 1.21s
# 230:	learn: 0.1956189	total: 363ms	remaining: 1.21s
# 231:	learn: 0.1952237	total: 365ms	remaining: 1.21s
# 232:	learn: 0.1949819	total: 366ms	remaining: 1.2s
# 233:	learn: 0.1948293	total: 367ms	remaining: 1.2s
# 234:	learn: 0.1947170	total: 369ms	remaining: 1.2s
# 235:	learn: 0.1946759	total: 371ms	remaining: 1.2s
# 236:	learn: 0.1943503	total: 373ms	remaining: 1.2s
# 237:	learn: 0.1943008	total: 374ms	remaining: 1.2s
# 238:	learn: 0.1942313	total: 376ms	remaining: 1.2s
# 239:	learn: 0.1940530	total: 377ms	remaining: 1.19s
# 240:	learn: 0.1939135	total: 379ms	remaining: 1.19s
# 241:	learn: 0.1935259	total: 380ms	remaining: 1.19s
# 242:	learn: 0.1934620	total: 382ms	remaining: 1.19s
# 243:	learn: 0.1934214	total: 383ms	remaining: 1.19s
# 244:	learn: 0.1932939	total: 385ms	remaining: 1.19s
# 245:	learn: 0.1931699	total: 386ms	remaining: 1.18s
# 246:	learn: 0.1930807	total: 388ms	remaining: 1.18s
# 247:	learn: 0.1929107	total: 389ms	remaining: 1.18s
# 248:	learn: 0.1923878	total: 391ms	remaining: 1.18s
# 249:	learn: 0.1922609	total: 393ms	remaining: 1.18s
# 250:	learn: 0.1922208	total: 394ms	remaining: 1.18s
# 251:	learn: 0.1921005	total: 396ms	remaining: 1.17s
# 252:	learn: 0.1920832	total: 397ms	remaining: 1.17s
# 253:	learn: 0.1920252	total: 399ms	remaining: 1.17s
# 254:	learn: 0.1918817	total: 400ms	remaining: 1.17s
# 255:	learn: 0.1918094	total: 402ms	remaining: 1.17s
# 256:	learn: 0.1917629	total: 403ms	remaining: 1.17s
# 257:	learn: 0.1916233	total: 405ms	remaining: 1.16s
# 258:	learn: 0.1914825	total: 406ms	remaining: 1.16s
# 259:	learn: 0.1913647	total: 408ms	remaining: 1.16s
# 260:	learn: 0.1912477	total: 410ms	remaining: 1.16s
# 261:	learn: 0.1907647	total: 412ms	remaining: 1.16s
# 262:	learn: 0.1907220	total: 413ms	remaining: 1.16s
# 263:	learn: 0.1903100	total: 415ms	remaining: 1.16s
# 264:	learn: 0.1901263	total: 416ms	remaining: 1.15s
# 265:	learn: 0.1897489	total: 418ms	remaining: 1.15s
# 266:	learn: 0.1896784	total: 419ms	remaining: 1.15s
# 267:	learn: 0.1893559	total: 421ms	remaining: 1.15s
# 268:	learn: 0.1889644	total: 422ms	remaining: 1.15s
# 269:	learn: 0.1887450	total: 424ms	remaining: 1.15s
# 270:	learn: 0.1886067	total: 425ms	remaining: 1.14s
# 271:	learn: 0.1885151	total: 427ms	remaining: 1.14s
# 272:	learn: 0.1884977	total: 428ms	remaining: 1.14s
# 273:	learn: 0.1884112	total: 430ms	remaining: 1.14s
# 274:	learn: 0.1883452	total: 431ms	remaining: 1.14s
# 275:	learn: 0.1881612	total: 433ms	remaining: 1.14s
# 276:	learn: 0.1881200	total: 434ms	remaining: 1.13s
# 277:	learn: 0.1880810	total: 436ms	remaining: 1.13s
# 278:	learn: 0.1880469	total: 437ms	remaining: 1.13s
# 279:	learn: 0.1879512	total: 439ms	remaining: 1.13s
# 280:	learn: 0.1878919	total: 440ms	remaining: 1.13s
# 281:	learn: 0.1878436	total: 442ms	remaining: 1.13s
# 282:	learn: 0.1877583	total: 444ms	remaining: 1.12s
# 283:	learn: 0.1876201	total: 445ms	remaining: 1.12s
# 284:	learn: 0.1876046	total: 447ms	remaining: 1.12s
# 285:	learn: 0.1875472	total: 448ms	remaining: 1.12s
# 286:	learn: 0.1874595	total: 450ms	remaining: 1.12s
# 287:	learn: 0.1873429	total: 451ms	remaining: 1.11s
# 288:	learn: 0.1871978	total: 453ms	remaining: 1.11s
# 289:	learn: 0.1871810	total: 454ms	remaining: 1.11s
# 290:	learn: 0.1866632	total: 456ms	remaining: 1.11s
# 291:	learn: 0.1866396	total: 457ms	remaining: 1.11s
# 292:	learn: 0.1865890	total: 459ms	remaining: 1.11s
# 293:	learn: 0.1861970	total: 460ms	remaining: 1.1s
# 294:	learn: 0.1860299	total: 462ms	remaining: 1.1s
# 295:	learn: 0.1858268	total: 463ms	remaining: 1.1s
# 296:	learn: 0.1857773	total: 465ms	remaining: 1.1s
# 297:	learn: 0.1856093	total: 466ms	remaining: 1.1s
# 298:	learn: 0.1855675	total: 468ms	remaining: 1.1s
# 299:	learn: 0.1854252	total: 469ms	remaining: 1.09s
# 300:	learn: 0.1853881	total: 471ms	remaining: 1.09s
# 301:	learn: 0.1853610	total: 472ms	remaining: 1.09s
# 302:	learn: 0.1851432	total: 474ms	remaining: 1.09s
# 303:	learn: 0.1850905	total: 475ms	remaining: 1.09s
# 304:	learn: 0.1849962	total: 477ms	remaining: 1.09s
# 305:	learn: 0.1848778	total: 478ms	remaining: 1.08s
# 306:	learn: 0.1844918	total: 480ms	remaining: 1.08s
# 307:	learn: 0.1842675	total: 481ms	remaining: 1.08s
# 308:	learn: 0.1841053	total: 483ms	remaining: 1.08s
# 309:	learn: 0.1839715	total: 484ms	remaining: 1.08s
# 310:	learn: 0.1839491	total: 486ms	remaining: 1.07s
# 311:	learn: 0.1838349	total: 487ms	remaining: 1.07s
# 312:	learn: 0.1836594	total: 489ms	remaining: 1.07s
# 313:	learn: 0.1836097	total: 490ms	remaining: 1.07s
# 314:	learn: 0.1835273	total: 492ms	remaining: 1.07s
# 315:	learn: 0.1832340	total: 493ms	remaining: 1.07s
# 316:	learn: 0.1830949	total: 495ms	remaining: 1.06s
# 317:	learn: 0.1830349	total: 496ms	remaining: 1.06s
# 318:	learn: 0.1829848	total: 498ms	remaining: 1.06s
# 319:	learn: 0.1828202	total: 499ms	remaining: 1.06s
# 320:	learn: 0.1827876	total: 501ms	remaining: 1.06s
# 321:	learn: 0.1827397	total: 502ms	remaining: 1.06s
# 322:	learn: 0.1825502	total: 504ms	remaining: 1.06s
# 323:	learn: 0.1824908	total: 506ms	remaining: 1.05s
# 324:	learn: 0.1824253	total: 507ms	remaining: 1.05s
# 325:	learn: 0.1823829	total: 509ms	remaining: 1.05s
# 326:	learn: 0.1823405	total: 510ms	remaining: 1.05s
# 327:	learn: 0.1821075	total: 512ms	remaining: 1.05s
# 328:	learn: 0.1819214	total: 514ms	remaining: 1.05s
# 329:	learn: 0.1818203	total: 516ms	remaining: 1.05s
# 330:	learn: 0.1818109	total: 518ms	remaining: 1.05s
# 331:	learn: 0.1810791	total: 519ms	remaining: 1.04s
# 332:	learn: 0.1810145	total: 521ms	remaining: 1.04s
# 333:	learn: 0.1809929	total: 522ms	remaining: 1.04s
# 334:	learn: 0.1809324	total: 524ms	remaining: 1.04s
# 335:	learn: 0.1808340	total: 525ms	remaining: 1.04s
# 336:	learn: 0.1808002	total: 527ms	remaining: 1.04s
# 337:	learn: 0.1807228	total: 528ms	remaining: 1.03s
# 338:	learn: 0.1803032	total: 530ms	remaining: 1.03s
# 339:	learn: 0.1802708	total: 532ms	remaining: 1.03s
# 340:	learn: 0.1802032	total: 533ms	remaining: 1.03s
# 341:	learn: 0.1801457	total: 535ms	remaining: 1.03s
# 342:	learn: 0.1801072	total: 537ms	remaining: 1.03s
# 343:	learn: 0.1800977	total: 539ms	remaining: 1.03s
# 344:	learn: 0.1796341	total: 540ms	remaining: 1.03s
# 345:	learn: 0.1795865	total: 542ms	remaining: 1.02s
# 346:	learn: 0.1795312	total: 543ms	remaining: 1.02s
# 347:	learn: 0.1788260	total: 545ms	remaining: 1.02s
# 348:	learn: 0.1787349	total: 547ms	remaining: 1.02s
# 349:	learn: 0.1786571	total: 549ms	remaining: 1.02s
# 350:	learn: 0.1786394	total: 550ms	remaining: 1.02s
# 351:	learn: 0.1786246	total: 552ms	remaining: 1.02s
# 352:	learn: 0.1785158	total: 554ms	remaining: 1.01s
# 353:	learn: 0.1782252	total: 555ms	remaining: 1.01s
# 354:	learn: 0.1779415	total: 557ms	remaining: 1.01s
# 355:	learn: 0.1778208	total: 558ms	remaining: 1.01s
# 356:	learn: 0.1776659	total: 560ms	remaining: 1.01s
# 357:	learn: 0.1774908	total: 562ms	remaining: 1.01s
# 358:	learn: 0.1772407	total: 563ms	remaining: 1s
# 359:	learn: 0.1770213	total: 564ms	remaining: 1s
# 360:	learn: 0.1769473	total: 566ms	remaining: 1s
# 361:	learn: 0.1769003	total: 567ms	remaining: 1000ms
# 362:	learn: 0.1767898	total: 569ms	remaining: 998ms
# 363:	learn: 0.1767317	total: 571ms	remaining: 997ms
# 364:	learn: 0.1766024	total: 572ms	remaining: 995ms
# 365:	learn: 0.1764664	total: 573ms	remaining: 993ms
# 366:	learn: 0.1761670	total: 575ms	remaining: 992ms
# 367:	learn: 0.1760828	total: 576ms	remaining: 990ms
# 368:	learn: 0.1758724	total: 578ms	remaining: 988ms
# 369:	learn: 0.1757058	total: 579ms	remaining: 987ms
# 370:	learn: 0.1755814	total: 581ms	remaining: 985ms
# 371:	learn: 0.1755786	total: 583ms	remaining: 983ms
# 372:	learn: 0.1754665	total: 584ms	remaining: 982ms
# 373:	learn: 0.1751839	total: 586ms	remaining: 980ms
# 374:	learn: 0.1751409	total: 587ms	remaining: 979ms
# 375:	learn: 0.1751249	total: 589ms	remaining: 977ms
# 376:	learn: 0.1750483	total: 590ms	remaining: 976ms
# 377:	learn: 0.1749109	total: 592ms	remaining: 974ms
# 378:	learn: 0.1748705	total: 593ms	remaining: 972ms
# 379:	learn: 0.1747571	total: 595ms	remaining: 971ms
# 380:	learn: 0.1745610	total: 597ms	remaining: 969ms
# 381:	learn: 0.1745409	total: 598ms	remaining: 968ms
# 382:	learn: 0.1745042	total: 600ms	remaining: 966ms
# 383:	learn: 0.1744648	total: 601ms	remaining: 964ms
# 384:	learn: 0.1743857	total: 603ms	remaining: 963ms
# 385:	learn: 0.1743172	total: 604ms	remaining: 961ms
# 386:	learn: 0.1741507	total: 606ms	remaining: 960ms
# 387:	learn: 0.1740608	total: 608ms	remaining: 959ms
# 388:	learn: 0.1739607	total: 610ms	remaining: 958ms
# 389:	learn: 0.1738905	total: 611ms	remaining: 956ms
# 390:	learn: 0.1737785	total: 613ms	remaining: 954ms
# 391:	learn: 0.1737561	total: 614ms	remaining: 952ms
# 392:	learn: 0.1737408	total: 616ms	remaining: 951ms
# 393:	learn: 0.1736913	total: 617ms	remaining: 949ms
# 394:	learn: 0.1735474	total: 619ms	remaining: 947ms
# 395:	learn: 0.1729264	total: 620ms	remaining: 946ms
# 396:	learn: 0.1728818	total: 622ms	remaining: 944ms
# 397:	learn: 0.1727674	total: 623ms	remaining: 942ms
# 398:	learn: 0.1726947	total: 625ms	remaining: 941ms
# 399:	learn: 0.1726720	total: 626ms	remaining: 939ms
# 400:	learn: 0.1726100	total: 628ms	remaining: 937ms
# 401:	learn: 0.1725765	total: 629ms	remaining: 936ms
# 402:	learn: 0.1724905	total: 631ms	remaining: 934ms
# 403:	learn: 0.1723903	total: 632ms	remaining: 933ms
# 404:	learn: 0.1723771	total: 634ms	remaining: 931ms
# 405:	learn: 0.1723509	total: 635ms	remaining: 929ms
# 406:	learn: 0.1723236	total: 637ms	remaining: 928ms
# 407:	learn: 0.1723082	total: 638ms	remaining: 926ms
# 408:	learn: 0.1722832	total: 640ms	remaining: 924ms
# 409:	learn: 0.1722672	total: 641ms	remaining: 922ms
# 410:	learn: 0.1722071	total: 643ms	remaining: 921ms
# 411:	learn: 0.1720236	total: 644ms	remaining: 919ms
# 412:	learn: 0.1718321	total: 646ms	remaining: 918ms
# 413:	learn: 0.1717387	total: 647ms	remaining: 916ms
# 414:	learn: 0.1717217	total: 649ms	remaining: 915ms
# 415:	learn: 0.1714142	total: 650ms	remaining: 913ms
# 416:	learn: 0.1712065	total: 652ms	remaining: 911ms
# 417:	learn: 0.1711699	total: 653ms	remaining: 910ms
# 418:	learn: 0.1711272	total: 655ms	remaining: 908ms
# 419:	learn: 0.1710045	total: 656ms	remaining: 906ms
# 420:	learn: 0.1709681	total: 658ms	remaining: 905ms
# 421:	learn: 0.1705273	total: 659ms	remaining: 903ms
# 422:	learn: 0.1704355	total: 661ms	remaining: 902ms
# 423:	learn: 0.1703756	total: 663ms	remaining: 900ms
# 424:	learn: 0.1703131	total: 664ms	remaining: 898ms
# 425:	learn: 0.1702983	total: 665ms	remaining: 896ms
# 426:	learn: 0.1701770	total: 667ms	remaining: 894ms
# 427:	learn: 0.1700651	total: 668ms	remaining: 893ms
# 428:	learn: 0.1700198	total: 669ms	remaining: 891ms
# 429:	learn: 0.1699619	total: 671ms	remaining: 889ms
# 430:	learn: 0.1699287	total: 672ms	remaining: 888ms
# 431:	learn: 0.1699011	total: 674ms	remaining: 886ms
# 432:	learn: 0.1698849	total: 676ms	remaining: 885ms
# 433:	learn: 0.1697973	total: 677ms	remaining: 883ms
# 434:	learn: 0.1697283	total: 679ms	remaining: 882ms
# 435:	learn: 0.1696451	total: 681ms	remaining: 881ms
# 436:	learn: 0.1695339	total: 683ms	remaining: 879ms
# 437:	learn: 0.1694830	total: 684ms	remaining: 878ms
# 438:	learn: 0.1693851	total: 686ms	remaining: 876ms
# 439:	learn: 0.1692916	total: 687ms	remaining: 874ms
# 440:	learn: 0.1690051	total: 689ms	remaining: 873ms
# 441:	learn: 0.1689240	total: 690ms	remaining: 871ms
# 442:	learn: 0.1689009	total: 692ms	remaining: 870ms
# 443:	learn: 0.1688219	total: 693ms	remaining: 868ms
# 444:	learn: 0.1687803	total: 695ms	remaining: 866ms
# 445:	learn: 0.1687738	total: 696ms	remaining: 865ms
# 446:	learn: 0.1687009	total: 698ms	remaining: 863ms
# 447:	learn: 0.1685625	total: 700ms	remaining: 862ms
# 448:	learn: 0.1685150	total: 701ms	remaining: 861ms
# 449:	learn: 0.1684497	total: 703ms	remaining: 859ms
# 450:	learn: 0.1683613	total: 704ms	remaining: 857ms
# 451:	learn: 0.1683200	total: 706ms	remaining: 856ms
# 452:	learn: 0.1682242	total: 707ms	remaining: 854ms
# 453:	learn: 0.1679149	total: 709ms	remaining: 853ms
# 454:	learn: 0.1678595	total: 710ms	remaining: 851ms
# 455:	learn: 0.1678160	total: 712ms	remaining: 850ms
# 456:	learn: 0.1675778	total: 714ms	remaining: 848ms
# 457:	learn: 0.1675374	total: 715ms	remaining: 847ms
# 458:	learn: 0.1674797	total: 717ms	remaining: 845ms
# 459:	learn: 0.1673994	total: 719ms	remaining: 844ms
# 460:	learn: 0.1673696	total: 720ms	remaining: 842ms
# 461:	learn: 0.1673267	total: 722ms	remaining: 840ms
# 462:	learn: 0.1672276	total: 723ms	remaining: 839ms
# 463:	learn: 0.1670886	total: 725ms	remaining: 837ms
# 464:	learn: 0.1670455	total: 726ms	remaining: 835ms
# 465:	learn: 0.1670114	total: 728ms	remaining: 834ms
# 466:	learn: 0.1669821	total: 729ms	remaining: 832ms
# 467:	learn: 0.1669359	total: 731ms	remaining: 831ms
# 468:	learn: 0.1669226	total: 733ms	remaining: 830ms
# 469:	learn: 0.1668810	total: 734ms	remaining: 828ms
# 470:	learn: 0.1667728	total: 736ms	remaining: 826ms
# 471:	learn: 0.1666612	total: 738ms	remaining: 825ms
# 472:	learn: 0.1666221	total: 739ms	remaining: 824ms
# 473:	learn: 0.1663916	total: 741ms	remaining: 822ms
# 474:	learn: 0.1663234	total: 742ms	remaining: 820ms
# 475:	learn: 0.1662341	total: 744ms	remaining: 819ms
# 476:	learn: 0.1662148	total: 745ms	remaining: 817ms
# 477:	learn: 0.1661742	total: 747ms	remaining: 815ms
# 478:	learn: 0.1661311	total: 748ms	remaining: 813ms
# 479:	learn: 0.1659565	total: 749ms	remaining: 812ms
# 480:	learn: 0.1658198	total: 750ms	remaining: 810ms
# 481:	learn: 0.1655662	total: 752ms	remaining: 808ms
# 482:	learn: 0.1654805	total: 753ms	remaining: 806ms
# 483:	learn: 0.1654436	total: 755ms	remaining: 805ms
# 484:	learn: 0.1653880	total: 756ms	remaining: 803ms
# 485:	learn: 0.1652844	total: 758ms	remaining: 801ms
# 486:	learn: 0.1652461	total: 759ms	remaining: 800ms
# 487:	learn: 0.1651954	total: 761ms	remaining: 798ms
# 488:	learn: 0.1651666	total: 762ms	remaining: 796ms
# 489:	learn: 0.1649647	total: 763ms	remaining: 795ms
# 490:	learn: 0.1649463	total: 765ms	remaining: 793ms
# 491:	learn: 0.1648257	total: 767ms	remaining: 792ms
# 492:	learn: 0.1647826	total: 768ms	remaining: 790ms
# 493:	learn: 0.1646032	total: 769ms	remaining: 788ms
# 494:	learn: 0.1645031	total: 771ms	remaining: 787ms
# 495:	learn: 0.1644179	total: 773ms	remaining: 785ms
# 496:	learn: 0.1644018	total: 774ms	remaining: 784ms
# 497:	learn: 0.1643700	total: 776ms	remaining: 782ms
# 498:	learn: 0.1643095	total: 777ms	remaining: 780ms
# 499:	learn: 0.1642949	total: 778ms	remaining: 778ms
# 500:	learn: 0.1640144	total: 780ms	remaining: 776ms
# 501:	learn: 0.1638603	total: 781ms	remaining: 775ms
# 502:	learn: 0.1638134	total: 782ms	remaining: 773ms
# 503:	learn: 0.1637584	total: 784ms	remaining: 772ms
# 504:	learn: 0.1637170	total: 785ms	remaining: 770ms
# 505:	learn: 0.1636510	total: 787ms	remaining: 768ms
# 506:	learn: 0.1635805	total: 788ms	remaining: 767ms
# 507:	learn: 0.1635661	total: 790ms	remaining: 765ms
# 508:	learn: 0.1634155	total: 792ms	remaining: 764ms
# 509:	learn: 0.1633638	total: 793ms	remaining: 762ms
# 510:	learn: 0.1631816	total: 795ms	remaining: 760ms
# 511:	learn: 0.1631126	total: 796ms	remaining: 759ms
# 512:	learn: 0.1630736	total: 797ms	remaining: 757ms
# 513:	learn: 0.1630474	total: 799ms	remaining: 755ms
# 514:	learn: 0.1630200	total: 800ms	remaining: 754ms
# 515:	learn: 0.1628639	total: 802ms	remaining: 752ms
# 516:	learn: 0.1627486	total: 803ms	remaining: 750ms
# 517:	learn: 0.1626396	total: 805ms	remaining: 749ms
# 518:	learn: 0.1624016	total: 806ms	remaining: 747ms
# 519:	learn: 0.1623910	total: 808ms	remaining: 746ms
# 520:	learn: 0.1620605	total: 809ms	remaining: 744ms
# 521:	learn: 0.1620121	total: 811ms	remaining: 742ms
# 522:	learn: 0.1619998	total: 812ms	remaining: 741ms
# 523:	learn: 0.1619688	total: 814ms	remaining: 739ms
# 524:	learn: 0.1618469	total: 815ms	remaining: 737ms
# 525:	learn: 0.1617239	total: 817ms	remaining: 736ms
# 526:	learn: 0.1616558	total: 818ms	remaining: 734ms
# 527:	learn: 0.1615589	total: 819ms	remaining: 732ms
# 528:	learn: 0.1615280	total: 821ms	remaining: 731ms
# 529:	learn: 0.1614534	total: 822ms	remaining: 729ms
# 530:	learn: 0.1614249	total: 824ms	remaining: 727ms
# 531:	learn: 0.1613179	total: 825ms	remaining: 726ms
# 532:	learn: 0.1608652	total: 826ms	remaining: 724ms
# 533:	learn: 0.1607052	total: 828ms	remaining: 723ms
# 534:	learn: 0.1606697	total: 830ms	remaining: 721ms
# 535:	learn: 0.1606552	total: 831ms	remaining: 719ms
# 536:	learn: 0.1606243	total: 833ms	remaining: 718ms
# 537:	learn: 0.1605090	total: 834ms	remaining: 716ms
# 538:	learn: 0.1604960	total: 835ms	remaining: 714ms
# 539:	learn: 0.1604436	total: 837ms	remaining: 713ms
# 540:	learn: 0.1603620	total: 838ms	remaining: 711ms
# 541:	learn: 0.1603330	total: 840ms	remaining: 710ms
# 542:	learn: 0.1601964	total: 842ms	remaining: 709ms
# 543:	learn: 0.1601426	total: 843ms	remaining: 707ms
# 544:	learn: 0.1599348	total: 846ms	remaining: 706ms
# 545:	learn: 0.1599102	total: 847ms	remaining: 704ms
# 546:	learn: 0.1598964	total: 849ms	remaining: 703ms
# 547:	learn: 0.1598116	total: 850ms	remaining: 701ms
# 548:	learn: 0.1597188	total: 852ms	remaining: 700ms
# 549:	learn: 0.1596705	total: 853ms	remaining: 698ms
# 550:	learn: 0.1596237	total: 855ms	remaining: 697ms
# 551:	learn: 0.1596029	total: 856ms	remaining: 695ms
# 552:	learn: 0.1594403	total: 858ms	remaining: 693ms
# 553:	learn: 0.1592881	total: 859ms	remaining: 692ms
# 554:	learn: 0.1592812	total: 861ms	remaining: 690ms
# 555:	learn: 0.1592520	total: 862ms	remaining: 689ms
# 556:	learn: 0.1592027	total: 864ms	remaining: 687ms
# 557:	learn: 0.1591722	total: 865ms	remaining: 686ms
# 558:	learn: 0.1591269	total: 867ms	remaining: 684ms
# 559:	learn: 0.1590537	total: 869ms	remaining: 683ms
# 560:	learn: 0.1590177	total: 870ms	remaining: 681ms
# 561:	learn: 0.1589458	total: 872ms	remaining: 679ms
# 562:	learn: 0.1589069	total: 873ms	remaining: 678ms
# 563:	learn: 0.1587687	total: 875ms	remaining: 676ms
# 564:	learn: 0.1587190	total: 876ms	remaining: 675ms
# 565:	learn: 0.1586529	total: 878ms	remaining: 673ms
# 566:	learn: 0.1584952	total: 879ms	remaining: 671ms
# 567:	learn: 0.1583305	total: 881ms	remaining: 670ms
# 568:	learn: 0.1582864	total: 882ms	remaining: 668ms
# 569:	learn: 0.1582712	total: 884ms	remaining: 667ms
# 570:	learn: 0.1582404	total: 886ms	remaining: 666ms
# 571:	learn: 0.1582128	total: 887ms	remaining: 664ms
# 572:	learn: 0.1582039	total: 889ms	remaining: 662ms
# 573:	learn: 0.1581329	total: 890ms	remaining: 661ms
# 574:	learn: 0.1580884	total: 892ms	remaining: 659ms
# 575:	learn: 0.1580620	total: 893ms	remaining: 657ms
# 576:	learn: 0.1580372	total: 895ms	remaining: 656ms
# 577:	learn: 0.1580182	total: 896ms	remaining: 655ms
# 578:	learn: 0.1579172	total: 898ms	remaining: 653ms
# 579:	learn: 0.1578913	total: 900ms	remaining: 651ms
# 580:	learn: 0.1576848	total: 901ms	remaining: 650ms
# 581:	learn: 0.1575939	total: 903ms	remaining: 648ms
# 582:	learn: 0.1575393	total: 905ms	remaining: 647ms
# 583:	learn: 0.1574997	total: 906ms	remaining: 645ms
# 584:	learn: 0.1574796	total: 907ms	remaining: 644ms
# 585:	learn: 0.1574610	total: 909ms	remaining: 642ms
# 586:	learn: 0.1572901	total: 910ms	remaining: 641ms
# 587:	learn: 0.1572417	total: 912ms	remaining: 639ms
# 588:	learn: 0.1572295	total: 913ms	remaining: 637ms
# 589:	learn: 0.1572227	total: 915ms	remaining: 636ms
# 590:	learn: 0.1571296	total: 916ms	remaining: 634ms
# 591:	learn: 0.1570248	total: 918ms	remaining: 633ms
# 592:	learn: 0.1570078	total: 919ms	remaining: 631ms
# 593:	learn: 0.1569896	total: 921ms	remaining: 630ms
# 594:	learn: 0.1569857	total: 923ms	remaining: 628ms
# 595:	learn: 0.1569498	total: 924ms	remaining: 627ms
# 596:	learn: 0.1569010	total: 926ms	remaining: 625ms
# 597:	learn: 0.1568377	total: 927ms	remaining: 623ms
# 598:	learn: 0.1566942	total: 929ms	remaining: 622ms
# 599:	learn: 0.1566771	total: 930ms	remaining: 620ms
# 600:	learn: 0.1565022	total: 932ms	remaining: 619ms
# 601:	learn: 0.1564693	total: 933ms	remaining: 617ms
# 602:	learn: 0.1561931	total: 935ms	remaining: 615ms
# 603:	learn: 0.1560726	total: 936ms	remaining: 614ms
# 604:	learn: 0.1560007	total: 938ms	remaining: 612ms
# 605:	learn: 0.1558444	total: 939ms	remaining: 611ms
# 606:	learn: 0.1558149	total: 941ms	remaining: 609ms
# 607:	learn: 0.1558016	total: 943ms	remaining: 608ms
# 608:	learn: 0.1556545	total: 944ms	remaining: 606ms
# 609:	learn: 0.1556485	total: 946ms	remaining: 605ms
# 610:	learn: 0.1556348	total: 947ms	remaining: 603ms
# 611:	learn: 0.1555931	total: 949ms	remaining: 601ms
# 612:	learn: 0.1555550	total: 950ms	remaining: 600ms
# 613:	learn: 0.1555219	total: 952ms	remaining: 598ms
# 614:	learn: 0.1555064	total: 953ms	remaining: 597ms
# 615:	learn: 0.1554259	total: 955ms	remaining: 595ms
# 616:	learn: 0.1553525	total: 956ms	remaining: 594ms
# 617:	learn: 0.1553123	total: 958ms	remaining: 592ms
# 618:	learn: 0.1552403	total: 959ms	remaining: 591ms
# 619:	learn: 0.1552279	total: 961ms	remaining: 589ms
# 620:	learn: 0.1551894	total: 963ms	remaining: 587ms
# 621:	learn: 0.1551887	total: 964ms	remaining: 586ms
# 622:	learn: 0.1551625	total: 965ms	remaining: 584ms
# 623:	learn: 0.1551247	total: 967ms	remaining: 583ms
# 624:	learn: 0.1550680	total: 968ms	remaining: 581ms
# 625:	learn: 0.1549612	total: 970ms	remaining: 579ms
# 626:	learn: 0.1549200	total: 971ms	remaining: 578ms
# 627:	learn: 0.1548329	total: 973ms	remaining: 576ms
# 628:	learn: 0.1548245	total: 974ms	remaining: 575ms
# 629:	learn: 0.1548006	total: 976ms	remaining: 573ms
# 630:	learn: 0.1547160	total: 977ms	remaining: 571ms
# 631:	learn: 0.1546920	total: 979ms	remaining: 570ms
# 632:	learn: 0.1546564	total: 980ms	remaining: 568ms
# 633:	learn: 0.1545900	total: 982ms	remaining: 567ms
# 634:	learn: 0.1545763	total: 983ms	remaining: 565ms
# 635:	learn: 0.1545429	total: 984ms	remaining: 563ms
# 636:	learn: 0.1544499	total: 986ms	remaining: 562ms
# 637:	learn: 0.1543561	total: 987ms	remaining: 560ms
# 638:	learn: 0.1543377	total: 989ms	remaining: 558ms
# 639:	learn: 0.1541813	total: 990ms	remaining: 557ms
# 640:	learn: 0.1541553	total: 992ms	remaining: 555ms
# 641:	learn: 0.1541372	total: 994ms	remaining: 554ms
# 642:	learn: 0.1541086	total: 995ms	remaining: 552ms
# 643:	learn: 0.1540837	total: 996ms	remaining: 551ms
# 644:	learn: 0.1540485	total: 998ms	remaining: 549ms
# 645:	learn: 0.1540007	total: 999ms	remaining: 548ms
# 646:	learn: 0.1538401	total: 1s	remaining: 546ms
# 647:	learn: 0.1538183	total: 1s	remaining: 544ms
# 648:	learn: 0.1537821	total: 1s	remaining: 543ms
# 649:	learn: 0.1537770	total: 1s	remaining: 541ms
# 650:	learn: 0.1537365	total: 1.01s	remaining: 540ms
# 651:	learn: 0.1536113	total: 1.01s	remaining: 539ms
# 652:	learn: 0.1535275	total: 1.01s	remaining: 537ms
# 653:	learn: 0.1534273	total: 1.01s	remaining: 536ms
# 654:	learn: 0.1533377	total: 1.01s	remaining: 534ms
# 655:	learn: 0.1532260	total: 1.01s	remaining: 533ms
# 656:	learn: 0.1531988	total: 1.02s	remaining: 531ms
# 657:	learn: 0.1531620	total: 1.02s	remaining: 530ms
# 658:	learn: 0.1531029	total: 1.02s	remaining: 528ms
# 659:	learn: 0.1530593	total: 1.02s	remaining: 526ms
# 660:	learn: 0.1528910	total: 1.02s	remaining: 525ms
# 661:	learn: 0.1528486	total: 1.02s	remaining: 523ms
# 662:	learn: 0.1528244	total: 1.03s	remaining: 522ms
# 663:	learn: 0.1527905	total: 1.03s	remaining: 520ms
# 664:	learn: 0.1527577	total: 1.03s	remaining: 518ms
# 665:	learn: 0.1527346	total: 1.03s	remaining: 517ms
# 666:	learn: 0.1526599	total: 1.03s	remaining: 516ms
# 667:	learn: 0.1526232	total: 1.03s	remaining: 514ms
# 668:	learn: 0.1525912	total: 1.03s	remaining: 512ms
# 669:	learn: 0.1525600	total: 1.04s	remaining: 511ms
# 670:	learn: 0.1524981	total: 1.04s	remaining: 509ms
# 671:	learn: 0.1523838	total: 1.04s	remaining: 508ms
# 672:	learn: 0.1523492	total: 1.04s	remaining: 506ms
# 673:	learn: 0.1523043	total: 1.04s	remaining: 505ms
# 674:	learn: 0.1522143	total: 1.04s	remaining: 503ms
# 675:	learn: 0.1520974	total: 1.05s	remaining: 502ms
# 676:	learn: 0.1520707	total: 1.05s	remaining: 500ms
# 677:	learn: 0.1520041	total: 1.05s	remaining: 498ms
# 678:	learn: 0.1519776	total: 1.06s	remaining: 500ms
# 679:	learn: 0.1519284	total: 1.06s	remaining: 499ms
# 680:	learn: 0.1518842	total: 1.06s	remaining: 497ms
# 681:	learn: 0.1517956	total: 1.06s	remaining: 496ms
# 682:	learn: 0.1517742	total: 1.06s	remaining: 494ms
# 683:	learn: 0.1517378	total: 1.07s	remaining: 493ms
# 684:	learn: 0.1515602	total: 1.07s	remaining: 491ms
# 685:	learn: 0.1515213	total: 1.07s	remaining: 490ms
# 686:	learn: 0.1514883	total: 1.07s	remaining: 488ms
# 687:	learn: 0.1514441	total: 1.07s	remaining: 487ms
# 688:	learn: 0.1514054	total: 1.07s	remaining: 485ms
# 689:	learn: 0.1513691	total: 1.08s	remaining: 484ms
# 690:	learn: 0.1513423	total: 1.08s	remaining: 482ms
# 691:	learn: 0.1512663	total: 1.08s	remaining: 480ms
# 692:	learn: 0.1512378	total: 1.08s	remaining: 479ms
# 693:	learn: 0.1511934	total: 1.08s	remaining: 477ms
# 694:	learn: 0.1509008	total: 1.08s	remaining: 476ms
# 695:	learn: 0.1508835	total: 1.08s	remaining: 474ms
# 696:	learn: 0.1508696	total: 1.09s	remaining: 472ms
# 697:	learn: 0.1507970	total: 1.09s	remaining: 471ms
# 698:	learn: 0.1507745	total: 1.09s	remaining: 469ms
# 699:	learn: 0.1507662	total: 1.09s	remaining: 468ms
# 700:	learn: 0.1506013	total: 1.09s	remaining: 466ms
# 701:	learn: 0.1505230	total: 1.09s	remaining: 465ms
# 702:	learn: 0.1504452	total: 1.09s	remaining: 463ms
# 703:	learn: 0.1504160	total: 1.1s	remaining: 461ms
# 704:	learn: 0.1503184	total: 1.1s	remaining: 460ms
# 705:	learn: 0.1502721	total: 1.1s	remaining: 458ms
# 706:	learn: 0.1502595	total: 1.1s	remaining: 457ms
# 707:	learn: 0.1500985	total: 1.1s	remaining: 455ms
# 708:	learn: 0.1500682	total: 1.1s	remaining: 453ms
# 709:	learn: 0.1500211	total: 1.11s	remaining: 452ms
# 710:	learn: 0.1499563	total: 1.11s	remaining: 450ms
# 711:	learn: 0.1498666	total: 1.11s	remaining: 449ms
# 712:	learn: 0.1497739	total: 1.11s	remaining: 447ms
# 713:	learn: 0.1497127	total: 1.11s	remaining: 445ms
# 714:	learn: 0.1496865	total: 1.11s	remaining: 444ms
# 715:	learn: 0.1496577	total: 1.13s	remaining: 448ms
# 716:	learn: 0.1496412	total: 1.13s	remaining: 447ms
# 717:	learn: 0.1496184	total: 1.13s	remaining: 445ms
# 718:	learn: 0.1495408	total: 1.13s	remaining: 444ms
# 719:	learn: 0.1494860	total: 1.14s	remaining: 442ms
# 720:	learn: 0.1494501	total: 1.14s	remaining: 440ms
# 721:	learn: 0.1493088	total: 1.14s	remaining: 439ms
# 722:	learn: 0.1488898	total: 1.14s	remaining: 437ms
# 723:	learn: 0.1487156	total: 1.14s	remaining: 436ms
# 724:	learn: 0.1485622	total: 1.14s	remaining: 434ms
# 725:	learn: 0.1485279	total: 1.15s	remaining: 433ms
# 726:	learn: 0.1483788	total: 1.15s	remaining: 431ms
# 727:	learn: 0.1483636	total: 1.15s	remaining: 429ms
# 728:	learn: 0.1481891	total: 1.15s	remaining: 428ms
# 729:	learn: 0.1481536	total: 1.15s	remaining: 426ms
# 730:	learn: 0.1481260	total: 1.15s	remaining: 425ms
# 731:	learn: 0.1479637	total: 1.16s	remaining: 423ms
# 732:	learn: 0.1479174	total: 1.16s	remaining: 421ms
# 733:	learn: 0.1478684	total: 1.16s	remaining: 420ms
# 734:	learn: 0.1478488	total: 1.16s	remaining: 418ms
# 735:	learn: 0.1477811	total: 1.16s	remaining: 417ms
# 736:	learn: 0.1477033	total: 1.16s	remaining: 415ms
# 737:	learn: 0.1476833	total: 1.16s	remaining: 413ms
# 738:	learn: 0.1476388	total: 1.17s	remaining: 412ms
# 739:	learn: 0.1476317	total: 1.17s	remaining: 410ms
# 740:	learn: 0.1475898	total: 1.17s	remaining: 409ms
# 741:	learn: 0.1475721	total: 1.17s	remaining: 407ms
# 742:	learn: 0.1475514	total: 1.17s	remaining: 406ms
# 743:	learn: 0.1474968	total: 1.17s	remaining: 404ms
# 744:	learn: 0.1473872	total: 1.18s	remaining: 402ms
# 745:	learn: 0.1473260	total: 1.18s	remaining: 401ms
# 746:	learn: 0.1472374	total: 1.18s	remaining: 399ms
# 747:	learn: 0.1472324	total: 1.18s	remaining: 398ms
# 748:	learn: 0.1471592	total: 1.18s	remaining: 396ms
# 749:	learn: 0.1471109	total: 1.18s	remaining: 395ms
# 750:	learn: 0.1470328	total: 1.19s	remaining: 393ms
# 751:	learn: 0.1469272	total: 1.19s	remaining: 391ms
# 752:	learn: 0.1469163	total: 1.19s	remaining: 390ms
# 753:	learn: 0.1469032	total: 1.19s	remaining: 388ms
# 754:	learn: 0.1468918	total: 1.19s	remaining: 387ms
# 755:	learn: 0.1468430	total: 1.19s	remaining: 385ms
# 756:	learn: 0.1468312	total: 1.19s	remaining: 383ms
# 757:	learn: 0.1468136	total: 1.2s	remaining: 382ms
# 758:	learn: 0.1467762	total: 1.2s	remaining: 380ms
# 759:	learn: 0.1467336	total: 1.2s	remaining: 379ms
# 760:	learn: 0.1466499	total: 1.2s	remaining: 377ms
# 761:	learn: 0.1466175	total: 1.2s	remaining: 375ms
# 762:	learn: 0.1465055	total: 1.2s	remaining: 374ms
# 763:	learn: 0.1464679	total: 1.21s	remaining: 372ms
# 764:	learn: 0.1464345	total: 1.21s	remaining: 371ms
# 765:	learn: 0.1464209	total: 1.21s	remaining: 369ms
# 766:	learn: 0.1463770	total: 1.21s	remaining: 367ms
# 767:	learn: 0.1463551	total: 1.21s	remaining: 366ms
# 768:	learn: 0.1460595	total: 1.21s	remaining: 364ms
# 769:	learn: 0.1460221	total: 1.21s	remaining: 363ms
# 770:	learn: 0.1460062	total: 1.22s	remaining: 361ms
# 771:	learn: 0.1459696	total: 1.22s	remaining: 360ms
# 772:	learn: 0.1459459	total: 1.22s	remaining: 358ms
# 773:	learn: 0.1458785	total: 1.22s	remaining: 356ms
# 774:	learn: 0.1458420	total: 1.22s	remaining: 355ms
# 775:	learn: 0.1458227	total: 1.22s	remaining: 353ms
# 776:	learn: 0.1457726	total: 1.23s	remaining: 352ms
# 777:	learn: 0.1456829	total: 1.23s	remaining: 350ms
# 778:	learn: 0.1456364	total: 1.23s	remaining: 349ms
# 779:	learn: 0.1455989	total: 1.23s	remaining: 347ms
# 780:	learn: 0.1455815	total: 1.23s	remaining: 345ms
# 781:	learn: 0.1455407	total: 1.23s	remaining: 344ms
# 782:	learn: 0.1455037	total: 1.24s	remaining: 342ms
# 783:	learn: 0.1454209	total: 1.24s	remaining: 341ms
# 784:	learn: 0.1453901	total: 1.24s	remaining: 339ms
# 785:	learn: 0.1452092	total: 1.24s	remaining: 338ms
# 786:	learn: 0.1451262	total: 1.24s	remaining: 336ms
# 787:	learn: 0.1450916	total: 1.24s	remaining: 334ms
# 788:	learn: 0.1450680	total: 1.24s	remaining: 333ms
# 789:	learn: 0.1450015	total: 1.25s	remaining: 331ms
# 790:	learn: 0.1449725	total: 1.25s	remaining: 329ms
# 791:	learn: 0.1449181	total: 1.25s	remaining: 328ms
# 792:	learn: 0.1449109	total: 1.25s	remaining: 326ms
# 793:	learn: 0.1448852	total: 1.25s	remaining: 325ms
# 794:	learn: 0.1448807	total: 1.25s	remaining: 323ms
# 795:	learn: 0.1448709	total: 1.25s	remaining: 321ms
# 796:	learn: 0.1448473	total: 1.26s	remaining: 320ms
# 797:	learn: 0.1448074	total: 1.26s	remaining: 318ms
# 798:	learn: 0.1446651	total: 1.26s	remaining: 317ms
# 799:	learn: 0.1446552	total: 1.26s	remaining: 315ms
# 800:	learn: 0.1446008	total: 1.26s	remaining: 314ms
# 801:	learn: 0.1445924	total: 1.26s	remaining: 312ms
# 802:	learn: 0.1445721	total: 1.26s	remaining: 310ms
# 803:	learn: 0.1444787	total: 1.27s	remaining: 309ms
# 804:	learn: 0.1443943	total: 1.27s	remaining: 307ms
# 805:	learn: 0.1443517	total: 1.27s	remaining: 306ms
# 806:	learn: 0.1442995	total: 1.27s	remaining: 304ms
# 807:	learn: 0.1442889	total: 1.27s	remaining: 302ms
# 808:	learn: 0.1442217	total: 1.27s	remaining: 301ms
# 809:	learn: 0.1441914	total: 1.27s	remaining: 299ms
# 810:	learn: 0.1440966	total: 1.28s	remaining: 298ms
# 811:	learn: 0.1440768	total: 1.28s	remaining: 296ms
# 812:	learn: 0.1440544	total: 1.28s	remaining: 294ms
# 813:	learn: 0.1440354	total: 1.28s	remaining: 293ms
# 814:	learn: 0.1440043	total: 1.28s	remaining: 291ms
# 815:	learn: 0.1439953	total: 1.28s	remaining: 290ms
# 816:	learn: 0.1439078	total: 1.29s	remaining: 288ms
# 817:	learn: 0.1438872	total: 1.29s	remaining: 287ms
# 818:	learn: 0.1438410	total: 1.29s	remaining: 285ms
# 819:	learn: 0.1438377	total: 1.29s	remaining: 283ms
# 820:	learn: 0.1438322	total: 1.29s	remaining: 282ms
# 821:	learn: 0.1438267	total: 1.29s	remaining: 280ms
# 822:	learn: 0.1437905	total: 1.29s	remaining: 279ms
# 823:	learn: 0.1437556	total: 1.3s	remaining: 277ms
# 824:	learn: 0.1437497	total: 1.3s	remaining: 275ms
# 825:	learn: 0.1436988	total: 1.3s	remaining: 274ms
# 826:	learn: 0.1436551	total: 1.3s	remaining: 272ms
# 827:	learn: 0.1435753	total: 1.3s	remaining: 271ms
# 828:	learn: 0.1435094	total: 1.3s	remaining: 269ms
# 829:	learn: 0.1434636	total: 1.31s	remaining: 268ms
# 830:	learn: 0.1434287	total: 1.31s	remaining: 266ms
# 831:	learn: 0.1433449	total: 1.31s	remaining: 264ms
# 832:	learn: 0.1433054	total: 1.31s	remaining: 263ms
# 833:	learn: 0.1433014	total: 1.31s	remaining: 261ms
# 834:	learn: 0.1432987	total: 1.31s	remaining: 260ms
# 835:	learn: 0.1432960	total: 1.31s	remaining: 258ms
# 836:	learn: 0.1432318	total: 1.32s	remaining: 256ms
# 837:	learn: 0.1431903	total: 1.32s	remaining: 255ms
# 838:	learn: 0.1431834	total: 1.32s	remaining: 253ms
# 839:	learn: 0.1431453	total: 1.32s	remaining: 252ms
# 840:	learn: 0.1430911	total: 1.32s	remaining: 250ms
# 841:	learn: 0.1430726	total: 1.32s	remaining: 248ms
# 842:	learn: 0.1430482	total: 1.32s	remaining: 247ms
# 843:	learn: 0.1430398	total: 1.33s	remaining: 245ms
# 844:	learn: 0.1430382	total: 1.33s	remaining: 244ms
# 845:	learn: 0.1430167	total: 1.33s	remaining: 242ms
# 846:	learn: 0.1429825	total: 1.33s	remaining: 240ms
# 847:	learn: 0.1429639	total: 1.33s	remaining: 239ms
# 848:	learn: 0.1428966	total: 1.33s	remaining: 237ms
# 849:	learn: 0.1428729	total: 1.33s	remaining: 236ms
# 850:	learn: 0.1427872	total: 1.34s	remaining: 234ms
# 851:	learn: 0.1427658	total: 1.34s	remaining: 233ms
# 852:	learn: 0.1427653	total: 1.34s	remaining: 231ms
# 853:	learn: 0.1427378	total: 1.34s	remaining: 229ms
# 854:	learn: 0.1426726	total: 1.34s	remaining: 228ms
# 855:	learn: 0.1426573	total: 1.34s	remaining: 226ms
# 856:	learn: 0.1425995	total: 1.35s	remaining: 225ms
# 857:	learn: 0.1425760	total: 1.35s	remaining: 223ms
# 858:	learn: 0.1425587	total: 1.35s	remaining: 222ms
# 859:	learn: 0.1425212	total: 1.35s	remaining: 220ms
# 860:	learn: 0.1424862	total: 1.35s	remaining: 219ms
# 861:	learn: 0.1424811	total: 1.35s	remaining: 217ms
# 862:	learn: 0.1424786	total: 1.36s	remaining: 215ms
# 863:	learn: 0.1424268	total: 1.36s	remaining: 214ms
# 864:	learn: 0.1423266	total: 1.36s	remaining: 212ms
# 865:	learn: 0.1422448	total: 1.36s	remaining: 211ms
# 866:	learn: 0.1422318	total: 1.36s	remaining: 209ms
# 867:	learn: 0.1422234	total: 1.36s	remaining: 208ms
# 868:	learn: 0.1421487	total: 1.37s	remaining: 206ms
# 869:	learn: 0.1421252	total: 1.37s	remaining: 204ms
# 870:	learn: 0.1421238	total: 1.37s	remaining: 203ms
# 871:	learn: 0.1420596	total: 1.37s	remaining: 201ms
# 872:	learn: 0.1420399	total: 1.37s	remaining: 200ms
# 873:	learn: 0.1420118	total: 1.37s	remaining: 198ms
# 874:	learn: 0.1419598	total: 1.38s	remaining: 196ms
# 875:	learn: 0.1419437	total: 1.38s	remaining: 195ms
# 876:	learn: 0.1419341	total: 1.38s	remaining: 193ms
# 877:	learn: 0.1419101	total: 1.38s	remaining: 192ms
# 878:	learn: 0.1418646	total: 1.38s	remaining: 190ms
# 879:	learn: 0.1418279	total: 1.38s	remaining: 189ms
# 880:	learn: 0.1417427	total: 1.39s	remaining: 187ms
# 881:	learn: 0.1417185	total: 1.39s	remaining: 186ms
# 882:	learn: 0.1415995	total: 1.39s	remaining: 184ms
# 883:	learn: 0.1415697	total: 1.39s	remaining: 182ms
# 884:	learn: 0.1415297	total: 1.39s	remaining: 181ms
# 885:	learn: 0.1415115	total: 1.39s	remaining: 179ms
# 886:	learn: 0.1414702	total: 1.39s	remaining: 178ms
# 887:	learn: 0.1413698	total: 1.4s	remaining: 176ms
# 888:	learn: 0.1413667	total: 1.4s	remaining: 174ms
# 889:	learn: 0.1413552	total: 1.4s	remaining: 173ms
# 890:	learn: 0.1413280	total: 1.4s	remaining: 171ms
# 891:	learn: 0.1412668	total: 1.4s	remaining: 170ms
# 892:	learn: 0.1412283	total: 1.4s	remaining: 168ms
# 893:	learn: 0.1412236	total: 1.41s	remaining: 167ms
# 894:	learn: 0.1411422	total: 1.41s	remaining: 165ms
# 895:	learn: 0.1411311	total: 1.41s	remaining: 163ms
# 896:	learn: 0.1410774	total: 1.41s	remaining: 162ms
# 897:	learn: 0.1410398	total: 1.41s	remaining: 160ms
# 898:	learn: 0.1410039	total: 1.41s	remaining: 159ms
# 899:	learn: 0.1409770	total: 1.41s	remaining: 157ms
# 900:	learn: 0.1409407	total: 1.42s	remaining: 156ms
# 901:	learn: 0.1409314	total: 1.42s	remaining: 154ms
# 902:	learn: 0.1409104	total: 1.42s	remaining: 153ms
# 903:	learn: 0.1408964	total: 1.42s	remaining: 151ms
# 904:	learn: 0.1408664	total: 1.42s	remaining: 149ms
# 905:	learn: 0.1408618	total: 1.42s	remaining: 148ms
# 906:	learn: 0.1407984	total: 1.43s	remaining: 146ms
# 907:	learn: 0.1407335	total: 1.43s	remaining: 145ms
# 908:	learn: 0.1406666	total: 1.43s	remaining: 143ms
# 909:	learn: 0.1406496	total: 1.43s	remaining: 141ms
# 910:	learn: 0.1406456	total: 1.43s	remaining: 140ms
# 911:	learn: 0.1406009	total: 1.43s	remaining: 138ms
# 912:	learn: 0.1405933	total: 1.44s	remaining: 137ms
# 913:	learn: 0.1405647	total: 1.44s	remaining: 135ms
# 914:	learn: 0.1404791	total: 1.44s	remaining: 134ms
# 915:	learn: 0.1404489	total: 1.44s	remaining: 132ms
# 916:	learn: 0.1404473	total: 1.44s	remaining: 130ms
# 917:	learn: 0.1403944	total: 1.44s	remaining: 129ms
# 918:	learn: 0.1403583	total: 1.44s	remaining: 127ms
# 919:	learn: 0.1403537	total: 1.45s	remaining: 126ms
# 920:	learn: 0.1403438	total: 1.45s	remaining: 124ms
# 921:	learn: 0.1403313	total: 1.45s	remaining: 123ms
# 922:	learn: 0.1401793	total: 1.45s	remaining: 121ms
# 923:	learn: 0.1401545	total: 1.45s	remaining: 119ms
# 924:	learn: 0.1400251	total: 1.45s	remaining: 118ms
# 925:	learn: 0.1399460	total: 1.45s	remaining: 116ms
# 926:	learn: 0.1398777	total: 1.46s	remaining: 115ms
# 927:	learn: 0.1398652	total: 1.46s	remaining: 113ms
# 928:	learn: 0.1398388	total: 1.46s	remaining: 112ms
# 929:	learn: 0.1398254	total: 1.46s	remaining: 110ms
# 930:	learn: 0.1398186	total: 1.46s	remaining: 108ms
# 931:	learn: 0.1397971	total: 1.46s	remaining: 107ms
# 932:	learn: 0.1397597	total: 1.47s	remaining: 105ms
# 933:	learn: 0.1397197	total: 1.47s	remaining: 104ms
# 934:	learn: 0.1396712	total: 1.47s	remaining: 102ms
# 935:	learn: 0.1396539	total: 1.47s	remaining: 101ms
# 936:	learn: 0.1396476	total: 1.47s	remaining: 99ms
# 937:	learn: 0.1396233	total: 1.47s	remaining: 97.5ms
# 938:	learn: 0.1396128	total: 1.48s	remaining: 95.9ms
# 939:	learn: 0.1395871	total: 1.48s	remaining: 94.4ms
# 940:	learn: 0.1395760	total: 1.48s	remaining: 92.8ms
# 941:	learn: 0.1395669	total: 1.48s	remaining: 91.2ms
# 942:	learn: 0.1395265	total: 1.48s	remaining: 89.7ms
# 943:	learn: 0.1395016	total: 1.49s	remaining: 88.1ms
# 944:	learn: 0.1394856	total: 1.49s	remaining: 86.5ms
# 945:	learn: 0.1394735	total: 1.49s	remaining: 85ms
# 946:	learn: 0.1394416	total: 1.49s	remaining: 83.4ms
# 947:	learn: 0.1394361	total: 1.49s	remaining: 81.8ms
# 948:	learn: 0.1393997	total: 1.49s	remaining: 80.2ms
# 949:	learn: 0.1393800	total: 1.5s	remaining: 78.7ms
# 950:	learn: 0.1393729	total: 1.5s	remaining: 77.1ms
# 951:	learn: 0.1393381	total: 1.5s	remaining: 75.6ms
# 952:	learn: 0.1393319	total: 1.5s	remaining: 74ms
# 953:	learn: 0.1393230	total: 1.5s	remaining: 72.4ms
# 954:	learn: 0.1393004	total: 1.5s	remaining: 70.8ms
# 955:	learn: 0.1392360	total: 1.5s	remaining: 69.2ms
# 956:	learn: 0.1392251	total: 1.5s	remaining: 67.7ms
# 957:	learn: 0.1392075	total: 1.51s	remaining: 66.1ms
# 958:	learn: 0.1391225	total: 1.51s	remaining: 64.5ms
# 959:	learn: 0.1391167	total: 1.51s	remaining: 62.9ms
# 960:	learn: 0.1390901	total: 1.51s	remaining: 61.4ms
# 961:	learn: 0.1390854	total: 1.51s	remaining: 59.8ms
# 962:	learn: 0.1390695	total: 1.52s	remaining: 58.3ms
# 963:	learn: 0.1390362	total: 1.52s	remaining: 56.7ms
# 964:	learn: 0.1390263	total: 1.52s	remaining: 55.1ms
# 965:	learn: 0.1389977	total: 1.52s	remaining: 53.5ms
# 966:	learn: 0.1389861	total: 1.52s	remaining: 52ms
# 967:	learn: 0.1389285	total: 1.52s	remaining: 50.4ms
# 968:	learn: 0.1388978	total: 1.53s	remaining: 48.8ms
# 969:	learn: 0.1387780	total: 1.53s	remaining: 47.2ms
# 970:	learn: 0.1387488	total: 1.53s	remaining: 45.7ms
# 971:	learn: 0.1387474	total: 1.53s	remaining: 44.1ms
# 972:	learn: 0.1387234	total: 1.53s	remaining: 42.5ms
# 973:	learn: 0.1387182	total: 1.53s	remaining: 41ms
# 974:	learn: 0.1386744	total: 1.53s	remaining: 39.4ms
# 975:	learn: 0.1386305	total: 1.54s	remaining: 37.8ms
# 976:	learn: 0.1386185	total: 1.54s	remaining: 36.2ms
# 977:	learn: 0.1386145	total: 1.54s	remaining: 34.7ms
# 978:	learn: 0.1385874	total: 1.54s	remaining: 33.1ms
# 979:	learn: 0.1385643	total: 1.54s	remaining: 31.5ms
# 980:	learn: 0.1385301	total: 1.54s	remaining: 29.9ms
# 981:	learn: 0.1384979	total: 1.55s	remaining: 28.4ms
# 982:	learn: 0.1384451	total: 1.55s	remaining: 26.8ms
# 983:	learn: 0.1383939	total: 1.55s	remaining: 25.2ms
# 984:	learn: 0.1383447	total: 1.55s	remaining: 23.6ms
# 985:	learn: 0.1383433	total: 1.55s	remaining: 22.1ms
# 986:	learn: 0.1383306	total: 1.55s	remaining: 20.5ms
# 987:	learn: 0.1383224	total: 1.56s	remaining: 18.9ms
# 988:	learn: 0.1381057	total: 1.56s	remaining: 17.3ms
# 989:	learn: 0.1380927	total: 1.56s	remaining: 15.8ms
# 990:	learn: 0.1380753	total: 1.56s	remaining: 14.2ms
# 991:	learn: 0.1378980	total: 1.56s	remaining: 12.6ms
# 992:	learn: 0.1378607	total: 1.56s	remaining: 11ms
# 993:	learn: 0.1378444	total: 1.57s	remaining: 9.46ms
# 994:	learn: 0.1378386	total: 1.57s	remaining: 7.88ms
# 995:	learn: 0.1378233	total: 1.57s	remaining: 6.31ms
# 996:	learn: 0.1377716	total: 1.57s	remaining: 4.73ms
# 997:	learn: 0.1377595	total: 1.57s	remaining: 3.15ms
# 998:	learn: 0.1377443	total: 1.57s	remaining: 1.58ms
# 999:	learn: 0.1377265	total: 1.58s	remaining: 0us

# %%
# Feature importances
fi_df = pd.DataFrame({'feature': cols})
fi_df['importance'] = np.mean(feature_importances, axis=0)
fi_df['std'] = np.std(feature_importances, axis=0)
fi_df['min'] = np.min(feature_importances, axis=0)
fi_df['max'] = np.max(feature_importances, axis=0)
fi_df = fi_df.sort_values('importance', ascending=False)
display(fi_df)
display(fi_df[['feature', 'importance']].sort_values('importance', ascending=True).plot.barh(x='feature'))
# Out:
#                         feature  importance       std        min        max
# 4         days_until_recitivism   31.246286  4.558950  24.737405  40.349158
# 5                    all_priors   22.183405  1.648106  18.997889  25.514022
# 2                  custody_days   16.189870  1.437753  12.462907  19.557968
# 3  in_custody_to_screening_days   14.568187  1.019935  12.111390  16.350381
# 1                         start    9.956027  1.073852   7.154313  11.850654
# 0       days_b_screening_arrest    5.856225  1.216437   3.632365   8.152291
# <AxesSubplot:ylabel='feature'>

# %%
out_cols = ['No-Recidivism', 'Non-Violent', 'Violent']
out_df = pd.DataFrame(preds_proba, columns=out_cols)

# Make sure that classes are in the right order and the highest prediction corresponds to predicted class
out_df['class'] = out_df.apply(lambda x: out_cols[np.argmax(x[out_cols])], axis=1)
assert (out_df['class'] == preds_class.ravel()).all()
out_df = out_df[out_cols]

out_df.to_csv('y_test.csv', index=False)

import urllib.parse
upload_link = urllib.parse.quote('share.streamlit.io/mkleinbort/kaggle-compas/main/app.py')
y_test_link = urllib.parse.quote('y_test.csv')
print(f'Predictions were exported to "y_test.csv". Upload them at https://{upload_link}')
out_df
# Out:
# Predictions were exported to "y_test.csv". Upload them at https://share.streamlit.io/mkleinbort/kaggle-compas/main/app.py
#      No-Recidivism  Non-Violent   Violent
# 0         0.984807     0.007642  0.007551
# 1         0.987862     0.007166  0.004972
# 2         0.000388     0.997992  0.001620
# 3         0.974578     0.012439  0.012983
# 4         0.959809     0.017244  0.022946
# ..             ...          ...       ...
# 944       0.977459     0.022073  0.000468
# 945       0.875593     0.118401  0.006006
# 946       0.956902     0.021736  0.021362
# 947       0.000818     0.985378  0.013804
# 948       0.979345     0.004128  0.016528
#
# [949 rows x 3 columns]

# %% [markdown]
# # Evaluations log
# ## 30/03/2021 22:18 JK
# ### Columns
# ['days_b_screening_arrest',
#  'start',
#  'custody_days',
#  'in_custody_to_screening_days',
#  'days_until_recitivism',
#  'all_priors']
#
# ### Hyperparams
# ```
# iterations=100,
# learning_rate=1,
# depth=2,
# loss_function='MultiClass'
# ```
#
# ## Results
# ### CV
# ```
# ROC-AUC 87.67% (STD: 1.96%)
# Race fairness: 82.86% (STD: 4.02%)
# Sex fairness: 84.82% (STD: 6.47%)
# Age fairness: 81.86% (STD: 4.66%)
# Score: 85.42%
# ```
#
# ### Online
# ```
# {
#   "accuracy": 0.8442265121761089,
#   "fairness": 0.606948047720613
# }
# Overall Score: 72.56%
# ```

# %%
# {
#   "accuracy": 0.8421805473187943,
#   "fairness": 0.6626350268234771
# }

# 75.24%

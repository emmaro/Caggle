# %%
pip install fairlearn
# Out:
# Requirement already satisfied: fairlearn in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (0.6.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from fairlearn) (1.6.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from fairlearn) (0.24.1)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from fairlearn) (1.2.3)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from fairlearn) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from pandas>=0.25.1->fairlearn) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from pandas>=0.25.1->fairlearn) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->fairlearn) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from scikit-learn>=0.22.1->fairlearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\emmar\documents\projects\caggle\venv\lib\site-packages (from scikit-learn>=0.22.1->fairlearn) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from catboost import Pool, CatBoostClassifier, cv
pd.options.display.max_columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Prep

# %%
X_train = pd.read_csv('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/train/X_train.csv', index_col='id')
y_train = pd.read_csv('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/train/y_train.csv', squeeze=True)
X_test = pd.read_csv ('https://raw.githubusercontent.com/mkleinbort/Kaggle-COMPAS/main/test/X_test.csv')
y_test = np.full(len(X_test), np.nan)

# %%
df = pd.concat([X_train, X_test])

df = df.drop(['v_screening_date'], axis=1) # duplicate of 'screening_date'
df = df.drop(['v_type_of_assessment'], axis=1) # duplicate of 'type_of_assessment'
df = df.drop(['type_of_assessment'], axis=1) # 0 variance

df['target'] = y_train.to_list() + list(y_test) # set target row-wise (ignoring indices)
# df['target'] = 0

# %%
# Engineer a new targets 
df['target_int'] = df['target'].replace({'No-Recidivism': 0, 'Non-Violent': 1, 'Violent': 2}) # so we can do regression
df['target_bool'] = df['target'].replace({'No-Recidivism': 0, 'Non-Violent': 1, 'Violent': 1}) # 0 - no-rec, 1 - rec
target_cols = ['target', 'target_int', 'target_bool']

# %%
# Engineer new date based features

"""
Custody: when someone is kept in prison until they go to court
Screening:  involves  using  a  brief  instrument  to  quickly  capture basic information 
    about a person’s risk to reoffend and is  used  to  determine  if  a  more  comprehensive  assessment
    is  warranted.  In  a  jail  setting,  everyone,  regardless  of  legal  status, should be screened 
    at booking.  Risk  screening  divides  the  jail  population  into  high-,  medium-,  and  low-risk 
    categories,  making  it  possible  to  direct  intervention  resources  first  to  the highest-risk individuals.



- c_arrest_date and c_offense_date are mutually exclusive and one of them is 99.8% likely to be filled
- c_arrest_date and c_are mutually exclusive
- start is number of days between c_jail_in and c_jail_out, maybe worth engineering total hours/minutes between
- screening_date is always filled
"""



days_cols = []

def days_between(d1, d2):
    try:
        try:
            d1 = datetime.strptime(d1, "%Y-%m-%d")
        except ValueError:
            d1 = datetime.strptime(d1, "%Y-%m-%d %H:%M:%S")
            
        try:
            d2 = datetime.strptime(d2, "%Y-%m-%d")
        except ValueError:
            d2 = datetime.strptime(d2, "%Y-%m-%d %H:%M:%S")
        return (d2 - d1).days
    except TypeError as e:
        return None

# mutually exclusive and one of them is always filled
df['c_bad_date'] = df['c_arrest_date'].fillna(df['c_offense_date']).fillna(df['in_custody']).fillna(df['screening_date'])

# how many days in custody
df['custody_days'] = df.apply(lambda x: days_between(x.out_custody, x.in_custody), axis=1)

# how quickly after going into custody did the person get screened (might indicate something?)
df['in_custody_to_screening_days'] = df.apply(lambda x: days_between(x.in_custody, x.screening_date), axis=1)

# questionable col because it is age related... Also corr=1 with age
df['birth_to_bad_days'] = df.apply(lambda x: days_between(x.date_of_birth, x.c_bad_date), axis=1)

# How many days passed until recitivism occcured. Golden feature!
df['days_until_recitivism'] = df.apply(lambda x: days_between(x.c_jail_out, x.r_jail_in), axis=1)

date_cols = [ 
    'c_arrest_date', 
    'c_offense_date',
    'screening_date', 
    'in_custody', 
    'out_custody', 
    'date_of_birth',
    'c_jail_in',
    'c_jail_out',
    'r_jail_in',
    'r_jail_out',

    # engineered
    'c_bad_date'
]

duration_cols = [
    'days_b_screening_arrest',
    'custody_days',
    'in_custody_to_screening_days',
    'birth_to_bad_days',
    'days_until_recitivism',
]

df.head()
# Out:
#                      name     first        last     sex date_of_birth  age  \
# 2677  nicholas staggewise  nicholas  staggewise    Male    1994-02-28   22
# 548          newton smith    newton       smith    Male    1995-01-28   21
# 4483       terrance irvin  terrance       irvin    Male    1984-04-10   32
# 9476      jaimie peterson    jaimie    peterson  Female    1986-01-02   30
# 199       ritesh sukhlall    ritesh    sukhlall    Male    1987-05-12   28
#
#          age_group              race  juv_fel_count  juv_misd_count  \
# 2677  Less than 25         Caucasian              0               0
# 548   Less than 25  African-American              0               1
# 4483       25 - 45  African-American              0               0
# 9476       25 - 45  African-American              0               0
# 199        25 - 45         Caucasian              0               0
#
#       juv_other_count  priors_count  days_b_screening_arrest  \
# 2677                0             2                     -1.0
# 548                 0             1                     -1.0
# 4483                0             6                     -1.0
# 9476                0             3                     -1.0
# 199                 0             2                      NaN
#
#                 c_jail_in           c_jail_out c_offense_date c_arrest_date  \
# 2677  2013-09-23 09:01:58  2013-09-27 03:54:42            NaN    2013-09-23
# 548   2013-06-16 12:36:42  2013-06-16 07:01:42     2013-06-15           NaN
# 4483  2013-10-11 05:38:14  2013-10-15 07:11:17     2013-10-11           NaN
# 9476  2014-01-11 06:56:43  2014-01-12 02:17:00     2014-01-11           NaN
# 199                   NaN                  NaN            NaN    2013-03-21
#
#      c_charge_degree                   c_charge_desc   r_jail_in  r_jail_out  \
# 2677               F           arrest case no charge         NaN         NaN
# 548                F   Grand Theft in the 3rd Degree         NaN         NaN
# 4483               F   Grand Theft in the 3rd Degree  2013-12-21  2014-02-21
# 9476               F  Felony Driving While Lic Suspd         NaN         NaN
# 199                F           arrest case no charge         NaN         NaN
#
#      screening_date  in_custody out_custody  start  id         target  \
# 2677     2013-09-24  2013-09-23  2013-09-27      3 NaN  No-Recidivism
# 548      2013-06-17  2013-06-16  2013-06-16      0 NaN        Violent
# 4483     2013-10-12  2013-10-11  2013-10-15      3 NaN    Non-Violent
# 9476     2014-01-12  2014-01-11  2014-01-12      0 NaN  No-Recidivism
# 199      2013-08-29         NaN         NaN      0 NaN  No-Recidivism
#
#       target_int  target_bool  c_bad_date  custody_days  \
# 2677         0.0          0.0  2013-09-23          -4.0
# 548          2.0          1.0  2013-06-15           0.0
# 4483         1.0          1.0  2013-10-11          -4.0
# 9476         0.0          0.0  2014-01-11          -1.0
# 199          0.0          0.0  2013-03-21           NaN
#
#       in_custody_to_screening_days  birth_to_bad_days  days_until_recitivism
# 2677                           1.0               7147                    NaN
# 548                            1.0               6713                    NaN
# 4483                           1.0              10776                   66.0
# 9476                           1.0              10236                    NaN
# 199                            NaN               9445                    NaN

# %%
# All prior counts
df['all_priors'] = df[[
    'juv_fel_count',
    'juv_misd_count', 
    'juv_other_count',
    'priors_count',
]].sum(axis=1)

# %%
# Has recidivism occured?
df['has_r_jail_in'] = df['r_jail_in'].notna()
df['has_r_jail_out'] = df['r_jail_out'].notna()

# %%
# fill missing values
df['c_charge_desc'] = df['c_charge_desc'].fillna('missing')

# %%
df.head()
# Out:
#                      name     first        last     sex date_of_birth  age  \
# 2677  nicholas staggewise  nicholas  staggewise    Male    1994-02-28   22
# 548          newton smith    newton       smith    Male    1995-01-28   21
# 4483       terrance irvin  terrance       irvin    Male    1984-04-10   32
# 9476      jaimie peterson    jaimie    peterson  Female    1986-01-02   30
# 199       ritesh sukhlall    ritesh    sukhlall    Male    1987-05-12   28
#
#          age_group              race  juv_fel_count  juv_misd_count  \
# 2677  Less than 25         Caucasian              0               0
# 548   Less than 25  African-American              0               1
# 4483       25 - 45  African-American              0               0
# 9476       25 - 45  African-American              0               0
# 199        25 - 45         Caucasian              0               0
#
#       juv_other_count  priors_count  days_b_screening_arrest  \
# 2677                0             2                     -1.0
# 548                 0             1                     -1.0
# 4483                0             6                     -1.0
# 9476                0             3                     -1.0
# 199                 0             2                      NaN
#
#                 c_jail_in           c_jail_out c_offense_date c_arrest_date  \
# 2677  2013-09-23 09:01:58  2013-09-27 03:54:42            NaN    2013-09-23
# 548   2013-06-16 12:36:42  2013-06-16 07:01:42     2013-06-15           NaN
# 4483  2013-10-11 05:38:14  2013-10-15 07:11:17     2013-10-11           NaN
# 9476  2014-01-11 06:56:43  2014-01-12 02:17:00     2014-01-11           NaN
# 199                   NaN                  NaN            NaN    2013-03-21
#
#      c_charge_degree                   c_charge_desc   r_jail_in  r_jail_out  \
# 2677               F           arrest case no charge         NaN         NaN
# 548                F   Grand Theft in the 3rd Degree         NaN         NaN
# 4483               F   Grand Theft in the 3rd Degree  2013-12-21  2014-02-21
# 9476               F  Felony Driving While Lic Suspd         NaN         NaN
# 199                F           arrest case no charge         NaN         NaN
#
#      screening_date  in_custody out_custody  start  id         target  \
# 2677     2013-09-24  2013-09-23  2013-09-27      3 NaN  No-Recidivism
# 548      2013-06-17  2013-06-16  2013-06-16      0 NaN        Violent
# 4483     2013-10-12  2013-10-11  2013-10-15      3 NaN    Non-Violent
# 9476     2014-01-12  2014-01-11  2014-01-12      0 NaN  No-Recidivism
# 199      2013-08-29         NaN         NaN      0 NaN  No-Recidivism
#
#       target_int  target_bool  c_bad_date  custody_days  \
# 2677         0.0          0.0  2013-09-23          -4.0
# 548          2.0          1.0  2013-06-15           0.0
# 4483         1.0          1.0  2013-10-11          -4.0
# 9476         0.0          0.0  2014-01-11          -1.0
# 199          0.0          0.0  2013-03-21           NaN
#
#       in_custody_to_screening_days  birth_to_bad_days  days_until_recitivism  \
# 2677                           1.0               7147                    NaN
# 548                            1.0               6713                    NaN
# 4483                           1.0              10776                   66.0
# 9476                           1.0              10236                    NaN
# 199                            NaN               9445                    NaN
#
#       all_priors  has_r_jail_in  has_r_jail_out
# 2677           2          False           False
# 548            2          False           False
# 4483           6           True            True
# 9476           3          False           False
# 199            2          False           False

# %%
##########################################
### Select features to use in modeling ###
##########################################

cols = [
#     'name', useless
#     'first', useless
#     'last', useless
#     'sex', # 0 importance + potential bias
#     'date_of_birth', date
#     'age', # innapropriate bias
#     'age_group', # innapropriate bias
#     'race', # innapropriate bias
#     'juv_fel_count',
#     'juv_misd_count', 
#     'juv_other_count',
#     'priors_count', 
    'days_b_screening_arrest', # + AUC, - fairness
#     'c_jail_in', date
#     'c_jail_out',date
#     'c_offense_date', date
#     'c_arrest_date', date
#     'c_charge_degree',  # 0 importance
#     'c_charge_desc',
#     'r_jail_in', date
#     'r_jail_out', date
#     'screening_date', date
#     'in_custody', date
#     'out_custody', date
    'start', # + AUC, + fairness
#     'target', target
#     'target_int', target
#     'target_bool', target
#     'c_bad_date', date
    'custody_days', # + AOC, + fairness
    'in_custody_to_screening_days', # + AUC, + fairness
#     'birth_to_bad_days', # corr=1 with age
#     'has_r_jail_in', + AUC, - fairness
#     'has_r_jail_out', # corr=1 with r_jail_in
    'days_until_recitivism', # golden feature!
    'all_priors', # good
]

cat_cols = [
#     'sex',  # innapropriate bias
#     'age_group', # innapropriate bias
#     'race', # innapropriate bias
#     'c_charge_degree', # 0 importance
#     'c_charge_desc',
]

# %%
# Count missing values
df[cols].isna().sum()/len(df[cols])
# Out:
# days_b_screening_arrest         0.056504
# start                           0.000000
# custody_days                    0.044065
# in_custody_to_screening_days    0.044065
# days_until_recitivism           0.855577
# all_priors                      0.000000
# dtype: float64

# %%
# Numeric correlations across numeric features
f, ax = plt.subplots(figsize=(16, 12))
corr = df[cols].corr()
mask = np.triu(corr)
sns.heatmap(corr.select_dtypes('number'), annot=True, center=0, mask=mask)
# Out:
# <AxesSubplot:>

# %%
df[cols].head()
# Out:
#       days_b_screening_arrest  start  custody_days  \
# 2677                     -1.0      3          -4.0
# 548                      -1.0      0           0.0
# 4483                     -1.0      3          -4.0
# 9476                     -1.0      0          -1.0
# 199                       NaN      0           NaN
#
#       in_custody_to_screening_days  days_until_recitivism  all_priors
# 2677                           1.0                    NaN           2
# 548                            1.0                    NaN           2
# 4483                           1.0                   66.0           6
# 9476                           1.0                    NaN           3
# 199                            NaN                    NaN           2

# %%
# df['race'] = df['race'].replace({'Native American': 'Other'})
# df['race'] = df['race'].replace({'Native American': 'Other', 'Asian': 'Other'})
df['race'] = df['race'].replace({'Native American': 'Other', 'Asian': 'Other', 'Hispanic': 'Other'})
df['race'].value_counts()
# Out:
# African-American    2266
# Caucasian           1701
# Other                776
# Name: race, dtype: int64

# %%
races = df.race.unique()
sexes = df.sex.unique()
age_groups = df.age_group.unique()

df.shape
# Out:
# (4743, 37)

# %% [markdown]
# # Cross Validation

# %%
df[cols] = df[cols].fillna(0)

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score

def fairness_score(y_true, y_pred, sensitive_features):
    mf = MetricFrame(roc_auc_score, y_true, y_pred, sensitive_features=sensitive_features)
    return (1 - np.sqrt(np.std(mf.by_group)))

# %%
df_train = df[df.target.notna()]

df_test = df[df.target.isna()]

# %% [markdown]
# # Multi-class Classification
# Non-recidivism / Non-Violent / Violent

# %%
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
import collections
from fairlearn.metrics import MetricFrame

TARGET_COL = 'target'

N_SPLITS = 5
N_REPEATS = 100

# Stratify based on intersections of race, age_group, sex and target.
strat_df = pd.DataFrame(df_train[TARGET_COL].astype('str') + df_train['race'] + df_train['sex'] + df_train['age_group'], columns=['name'])

# If cross section is too small for stratification to work (N < N_SPLITS) we mark it as an outlier
strat_df.loc[strat_df.groupby('name').name.transform('count').lt(N_SPLITS), 'name'] = 'Outliers'    

kf = RepeatedStratifiedKFold(n_splits=N_SPLITS, n_repeats=N_REPEATS, random_state=42)

roc_aucs = []
rms = []
sms = []
ams = []

feature_importances = []
for split_idx, (train, test) in enumerate(kf.split(df_train[cols], strat_df['name'])): # Stratified on race
    df_train_cv = df.iloc[train].reset_index(drop=True)
    df_eval_cv = df.iloc[test].reset_index(drop=True)
    
    train_dataset = Pool(data=df_train_cv[cols],
                         label=df_train_cv[TARGET_COL],
                         cat_features=cat_cols)

    eval_dataset = Pool(data=df_eval_cv[cols],
                        label=df_eval_cv[TARGET_COL],
                        cat_features=cat_cols)
    
    y_eval = pd.get_dummies(df_eval_cv[TARGET_COL]).to_numpy()
    # Initialize CatBoostClassifier
    model = CatBoostClassifier(iterations=100,
                               learning_rate=1,
                               depth=3,
                               loss_function='MultiClass')
    # Fit model
    model.fit(train_dataset, verbose=False)
#     # Get predicted probabilities for each class
    preds_proba = model.predict_proba(eval_dataset)
    
    roc_auc = roc_auc_score(y_eval, preds_proba, multi_class="ovo")
    rm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['race'])
    sm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['sex'])
    am = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['age_group'])
    
    roc_aucs.append(roc_auc)
    rms.append(rm)
    sms.append(sm)
    ams.append(am)
        
    roc_aucs.append(roc_auc)
    feature_importances.append(model.get_feature_importance())
    # avg_precs.append(avg_prec)
    race_fairness = 1 - np.sqrt(np.std(rm.by_group))
    sex_fairness = 1 - np.sqrt(np.std(sm.by_group))
    age_fairness = 1 - np.sqrt(np.std(am.by_group))
    print(f'Split {split_idx+1:2}: ROC-AUC: {roc_auc*100:.2f}%. '
          f'Fairness: R: {race_fairness*100:.2f}%, S: {sex_fairness*100:.2f}%, A: {age_fairness*100:.2f}%')
# Out:
# Split  1: ROC-AUC: 87.54%. Fairness: R: 80.22%, S: 77.41%, A: 80.19%
# Split  2: ROC-AUC: 86.61%. Fairness: R: 86.34%, S: 82.26%, A: 79.68%
# Split  3: ROC-AUC: 87.08%. Fairness: R: 75.97%, S: 94.26%, A: 85.03%
# Split  4: ROC-AUC: 88.41%. Fairness: R: 74.53%, S: 90.80%, A: 83.66%
# Split  5: ROC-AUC: 87.63%. Fairness: R: 79.60%, S: 82.02%, A: 79.01%
# Split  6: ROC-AUC: 87.47%. Fairness: R: 84.49%, S: 86.54%, A: 87.64%
# Split  7: ROC-AUC: 88.33%. Fairness: R: 81.45%, S: 89.71%, A: 93.65%
# Split  8: ROC-AUC: 86.45%. Fairness: R: 84.14%, S: 85.75%, A: 89.39%
# Split  9: ROC-AUC: 90.47%. Fairness: R: 90.13%, S: 76.89%, A: 76.27%
# Split 10: ROC-AUC: 86.92%. Fairness: R: 74.53%, S: 88.49%, A: 72.60%
# Split 11: ROC-AUC: 84.86%. Fairness: R: 86.36%, S: 85.81%, A: 81.41%
# Split 12: ROC-AUC: 85.43%. Fairness: R: 76.40%, S: 78.43%, A: 78.03%
# Split 13: ROC-AUC: 92.07%. Fairness: R: 84.69%, S: 82.04%, A: 83.44%
# Split 14: ROC-AUC: 88.64%. Fairness: R: 79.14%, S: 82.31%, A: 88.41%
# Split 15: ROC-AUC: 88.13%. Fairness: R: 88.10%, S: 78.89%, A: 79.49%
# Split 16: ROC-AUC: 86.42%. Fairness: R: 75.11%, S: 87.64%, A: 77.14%
# Split 17: ROC-AUC: 86.05%. Fairness: R: 84.78%, S: 94.56%, A: 86.30%
# Split 18: ROC-AUC: 87.77%. Fairness: R: 77.96%, S: 89.41%, A: 79.37%
# Split 19: ROC-AUC: 84.39%. Fairness: R: 77.82%, S: 78.87%, A: 80.28%
# Split 20: ROC-AUC: 92.96%. Fairness: R: 87.00%, S: 87.71%, A: 83.78%
# Split 21: ROC-AUC: 87.80%. Fairness: R: 81.13%, S: 88.67%, A: 81.20%
# Split 22: ROC-AUC: 85.37%. Fairness: R: 85.37%, S: 79.26%, A: 77.03%
# Split 23: ROC-AUC: 86.82%. Fairness: R: 82.31%, S: 75.29%, A: 84.55%
# Split 24: ROC-AUC: 86.24%. Fairness: R: 80.46%, S: 82.09%, A: 73.14%
# Split 25: ROC-AUC: 89.44%. Fairness: R: 83.12%, S: 86.72%, A: 80.62%
# Split 26: ROC-AUC: 90.49%. Fairness: R: 83.78%, S: 77.96%, A: 86.13%
# Split 27: ROC-AUC: 85.15%. Fairness: R: 82.94%, S: 90.41%, A: 82.27%
# Split 28: ROC-AUC: 91.03%. Fairness: R: 82.06%, S: 80.47%, A: 75.10%
# Split 29: ROC-AUC: 89.82%. Fairness: R: 83.04%, S: 86.86%, A: 80.65%
# Split 30: ROC-AUC: 86.24%. Fairness: R: 82.69%, S: 89.48%, A: 86.90%
# Split 31: ROC-AUC: 89.82%. Fairness: R: 80.41%, S: 77.98%, A: 81.74%
# Split 32: ROC-AUC: 87.47%. Fairness: R: 87.20%, S: 81.07%, A: 89.39%
# Split 33: ROC-AUC: 89.42%. Fairness: R: 93.10%, S: 95.88%, A: 84.83%
# Split 34: ROC-AUC: 85.42%. Fairness: R: 87.64%, S: 81.20%, A: 77.11%
# Split 35: ROC-AUC: 88.02%. Fairness: R: 77.35%, S: 79.23%, A: 89.41%
# Split 36: ROC-AUC: 88.55%. Fairness: R: 86.99%, S: 76.64%, A: 91.95%
# Split 37: ROC-AUC: 85.68%. Fairness: R: 78.20%, S: 80.74%, A: 87.99%
# Split 38: ROC-AUC: 89.44%. Fairness: R: 80.68%, S: 82.23%, A: 79.97%
# Split 39: ROC-AUC: 88.44%. Fairness: R: 85.08%, S: 91.72%, A: 76.95%
# Split 40: ROC-AUC: 87.36%. Fairness: R: 81.34%, S: 89.19%, A: 88.11%
# Split 41: ROC-AUC: 89.77%. Fairness: R: 79.68%, S: 84.95%, A: 84.50%
# Split 42: ROC-AUC: 89.83%. Fairness: R: 78.96%, S: 92.13%, A: 82.60%
# Split 43: ROC-AUC: 88.30%. Fairness: R: 86.03%, S: 83.50%, A: 81.58%
# Split 44: ROC-AUC: 88.19%. Fairness: R: 81.96%, S: 85.93%, A: 95.19%
# Split 45: ROC-AUC: 83.24%. Fairness: R: 87.51%, S: 82.93%, A: 79.01%
# Split 46: ROC-AUC: 88.97%. Fairness: R: 80.10%, S: 89.86%, A: 87.71%
# Split 47: ROC-AUC: 88.39%. Fairness: R: 86.64%, S: 85.62%, A: 79.44%
# Split 48: ROC-AUC: 86.78%. Fairness: R: 81.30%, S: 89.65%, A: 76.14%
# Split 49: ROC-AUC: 88.54%. Fairness: R: 81.22%, S: 83.32%, A: 79.42%
# Split 50: ROC-AUC: 88.78%. Fairness: R: 90.04%, S: 76.86%, A: 82.10%
# Split 51: ROC-AUC: 89.37%. Fairness: R: 82.88%, S: 92.17%, A: 89.81%
# Split 52: ROC-AUC: 88.60%. Fairness: R: 76.95%, S: 91.27%, A: 74.77%
# Split 53: ROC-AUC: 90.27%. Fairness: R: 86.92%, S: 86.71%, A: 87.81%
# Split 54: ROC-AUC: 87.57%. Fairness: R: 92.24%, S: 74.31%, A: 89.71%
# Split 55: ROC-AUC: 86.65%. Fairness: R: 84.19%, S: 90.53%, A: 87.56%
# Split 56: ROC-AUC: 88.65%. Fairness: R: 86.89%, S: 96.53%, A: 82.76%
# Split 57: ROC-AUC: 90.58%. Fairness: R: 78.35%, S: 77.92%, A: 80.07%
# Split 58: ROC-AUC: 83.47%. Fairness: R: 78.70%, S: 78.40%, A: 84.71%
# Split 59: ROC-AUC: 90.03%. Fairness: R: 84.57%, S: 90.35%, A: 80.85%
# Split 60: ROC-AUC: 90.03%. Fairness: R: 74.14%, S: 93.81%, A: 83.08%
# Split 61: ROC-AUC: 87.64%. Fairness: R: 85.84%, S: 83.80%, A: 79.63%
# Split 62: ROC-AUC: 89.08%. Fairness: R: 83.11%, S: 75.37%, A: 81.40%
# Split 63: ROC-AUC: 88.30%. Fairness: R: 78.87%, S: 85.37%, A: 83.29%
# Split 64: ROC-AUC: 85.14%. Fairness: R: 84.53%, S: 94.73%, A: 88.43%
# Split 65: ROC-AUC: 88.66%. Fairness: R: 90.66%, S: 84.85%, A: 83.56%
# Split 66: ROC-AUC: 85.71%. Fairness: R: 85.79%, S: 87.64%, A: 88.03%
# Split 67: ROC-AUC: 90.07%. Fairness: R: 79.18%, S: 90.33%, A: 77.66%
# Split 68: ROC-AUC: 89.33%. Fairness: R: 79.22%, S: 77.64%, A: 79.74%
# Split 69: ROC-AUC: 89.18%. Fairness: R: 81.45%, S: 84.85%, A: 88.02%
# Split 70: ROC-AUC: 86.04%. Fairness: R: 79.69%, S: 84.56%, A: 84.23%
# Split 71: ROC-AUC: 85.87%. Fairness: R: 91.13%, S: 70.09%, A: 78.10%
# Split 72: ROC-AUC: 85.67%. Fairness: R: 76.19%, S: 86.36%, A: 81.15%
# Split 73: ROC-AUC: 90.87%. Fairness: R: 77.98%, S: 81.97%, A: 94.63%
# Split 74: ROC-AUC: 87.81%. Fairness: R: 87.00%, S: 87.86%, A: 88.77%
# Split 75: ROC-AUC: 88.09%. Fairness: R: 87.65%, S: 81.92%, A: 84.19%
# Split 76: ROC-AUC: 88.64%. Fairness: R: 84.67%, S: 78.05%, A: 81.46%
# Split 77: ROC-AUC: 83.63%. Fairness: R: 88.39%, S: 89.93%, A: 84.51%
# Split 78: ROC-AUC: 88.88%. Fairness: R: 79.31%, S: 83.94%, A: 80.97%
# Split 79: ROC-AUC: 88.58%. Fairness: R: 74.56%, S: 84.32%, A: 88.16%
# Split 80: ROC-AUC: 87.30%. Fairness: R: 78.94%, S: 72.86%, A: 89.12%
# Split 81: ROC-AUC: 89.47%. Fairness: R: 84.07%, S: 82.18%, A: 78.60%
# Split 82: ROC-AUC: 86.93%. Fairness: R: 74.14%, S: 76.99%, A: 73.86%
# Split 83: ROC-AUC: 83.85%. Fairness: R: 80.45%, S: 79.04%, A: 88.67%
# Split 84: ROC-AUC: 91.41%. Fairness: R: 84.86%, S: 79.11%, A: 92.13%
# Split 85: ROC-AUC: 89.73%. Fairness: R: 76.85%, S: 81.57%, A: 88.19%
# Split 86: ROC-AUC: 87.04%. Fairness: R: 86.97%, S: 82.04%, A: 81.82%
# Split 87: ROC-AUC: 87.05%. Fairness: R: 82.18%, S: 76.21%, A: 76.81%
# Split 88: ROC-AUC: 89.19%. Fairness: R: 81.82%, S: 88.77%, A: 79.26%
# Split 89: ROC-AUC: 86.53%. Fairness: R: 83.16%, S: 81.92%, A: 85.42%
# Split 90: ROC-AUC: 87.48%. Fairness: R: 76.13%, S: 84.43%, A: 72.97%
# Split 91: ROC-AUC: 86.98%. Fairness: R: 84.47%, S: 91.64%, A: 84.30%
# Split 92: ROC-AUC: 86.30%. Fairness: R: 86.71%, S: 81.82%, A: 77.97%
# Split 93: ROC-AUC: 84.22%. Fairness: R: 80.26%, S: 79.43%, A: 84.19%
# Split 94: ROC-AUC: 89.25%. Fairness: R: 80.95%, S: 83.34%, A: 85.93%
# Split 95: ROC-AUC: 86.91%. Fairness: R: 87.46%, S: 74.88%, A: 78.91%
# Split 96: ROC-AUC: 88.09%. Fairness: R: 77.92%, S: 75.56%, A: 79.99%
# Split 97: ROC-AUC: 86.26%. Fairness: R: 85.21%, S: 75.42%, A: 78.03%
# Split 98: ROC-AUC: 89.75%. Fairness: R: 91.64%, S: 81.21%, A: 79.53%
# Split 99: ROC-AUC: 87.85%. Fairness: R: 78.55%, S: 80.45%, A: 78.60%
# Split 100: ROC-AUC: 88.60%. Fairness: R: 86.59%, S: 77.31%, A: 88.22%
# Split 101: ROC-AUC: 86.94%. Fairness: R: 88.24%, S: 86.70%, A: 79.96%
# Split 102: ROC-AUC: 91.32%. Fairness: R: 80.74%, S: 83.94%, A: 82.38%
# Split 103: ROC-AUC: 88.52%. Fairness: R: 77.13%, S: 79.58%, A: 88.60%
# Split 104: ROC-AUC: 87.91%. Fairness: R: 81.70%, S: 85.03%, A: 79.85%
# Split 105: ROC-AUC: 85.48%. Fairness: R: 84.79%, S: 75.65%, A: 83.93%
# Split 106: ROC-AUC: 87.04%. Fairness: R: 85.67%, S: 83.95%, A: 88.55%
# Split 107: ROC-AUC: 88.69%. Fairness: R: 80.67%, S: 86.31%, A: 79.98%
# Split 108: ROC-AUC: 86.95%. Fairness: R: 78.67%, S: 95.60%, A: 74.06%
# Split 109: ROC-AUC: 84.90%. Fairness: R: 83.53%, S: 79.41%, A: 79.13%
# Split 110: ROC-AUC: 88.35%. Fairness: R: 76.33%, S: 80.88%, A: 88.59%
# Split 111: ROC-AUC: 86.66%. Fairness: R: 81.68%, S: 85.61%, A: 82.29%
# Split 112: ROC-AUC: 88.10%. Fairness: R: 79.83%, S: 86.84%, A: 81.44%
# Split 113: ROC-AUC: 90.61%. Fairness: R: 92.67%, S: 95.36%, A: 93.12%
# Split 114: ROC-AUC: 86.44%. Fairness: R: 76.91%, S: 81.01%, A: 78.69%
# Split 115: ROC-AUC: 88.23%. Fairness: R: 86.28%, S: 93.82%, A: 75.92%
# Split 116: ROC-AUC: 86.71%. Fairness: R: 90.40%, S: 75.29%, A: 84.98%
# Split 117: ROC-AUC: 87.90%. Fairness: R: 92.97%, S: 90.35%, A: 75.15%
# Split 118: ROC-AUC: 91.31%. Fairness: R: 82.15%, S: 79.88%, A: 81.82%
# Split 119: ROC-AUC: 89.89%. Fairness: R: 78.47%, S: 87.06%, A: 75.20%
# Split 120: ROC-AUC: 86.76%. Fairness: R: 90.73%, S: 79.40%, A: 87.59%
# Split 121: ROC-AUC: 91.14%. Fairness: R: 78.68%, S: 79.59%, A: 80.83%
# Split 122: ROC-AUC: 90.39%. Fairness: R: 92.09%, S: 81.61%, A: 85.15%
# Split 123: ROC-AUC: 88.55%. Fairness: R: 86.98%, S: 86.51%, A: 84.29%
# Split 124: ROC-AUC: 85.64%. Fairness: R: 84.95%, S: 75.85%, A: 73.14%
# Split 125: ROC-AUC: 89.19%. Fairness: R: 80.98%, S: 94.50%, A: 84.41%
# Split 126: ROC-AUC: 89.99%. Fairness: R: 81.49%, S: 95.33%, A: 80.07%
# Split 127: ROC-AUC: 87.06%. Fairness: R: 83.27%, S: 78.36%, A: 82.83%
# Split 128: ROC-AUC: 90.25%. Fairness: R: 81.35%, S: 84.08%, A: 80.73%
# Split 129: ROC-AUC: 82.99%. Fairness: R: 91.73%, S: 87.51%, A: 81.24%
# Split 130: ROC-AUC: 86.47%. Fairness: R: 75.15%, S: 77.18%, A: 79.96%
# Split 131: ROC-AUC: 87.49%. Fairness: R: 82.98%, S: 85.20%, A: 87.45%
# Split 132: ROC-AUC: 85.49%. Fairness: R: 79.19%, S: 90.78%, A: 81.76%
# Split 133: ROC-AUC: 91.40%. Fairness: R: 83.40%, S: 80.06%, A: 86.63%
# Split 134: ROC-AUC: 87.01%. Fairness: R: 81.76%, S: 88.87%, A: 77.79%
# Split 135: ROC-AUC: 88.13%. Fairness: R: 87.16%, S: 87.10%, A: 90.55%
# Split 136: ROC-AUC: 84.40%. Fairness: R: 88.00%, S: 75.66%, A: 80.92%
# Split 137: ROC-AUC: 89.03%. Fairness: R: 79.79%, S: 85.09%, A: 81.42%
# Split 138: ROC-AUC: 85.39%. Fairness: R: 90.75%, S: 76.02%, A: 84.18%
# Split 139: ROC-AUC: 89.18%. Fairness: R: 79.72%, S: 90.23%, A: 76.42%
# Split 140: ROC-AUC: 92.07%. Fairness: R: 81.13%, S: 84.97%, A: 80.78%
# Split 141: ROC-AUC: 89.94%. Fairness: R: 80.12%, S: 79.95%, A: 84.63%
# Split 142: ROC-AUC: 90.59%. Fairness: R: 81.72%, S: 88.53%, A: 89.60%
# Split 143: ROC-AUC: 87.16%. Fairness: R: 83.15%, S: 87.86%, A: 77.31%
# Split 144: ROC-AUC: 85.45%. Fairness: R: 82.76%, S: 87.93%, A: 79.98%
# Split 145: ROC-AUC: 87.56%. Fairness: R: 81.99%, S: 73.74%, A: 73.34%
# Split 146: ROC-AUC: 87.56%. Fairness: R: 82.54%, S: 82.44%, A: 85.09%
# Split 147: ROC-AUC: 86.59%. Fairness: R: 75.31%, S: 85.44%, A: 82.31%
# Split 148: ROC-AUC: 89.39%. Fairness: R: 78.83%, S: 80.96%, A: 83.40%
# Split 149: ROC-AUC: 87.10%. Fairness: R: 79.12%, S: 74.65%, A: 85.06%
# Split 150: ROC-AUC: 88.30%. Fairness: R: 78.19%, S: 82.37%, A: 81.18%
# Split 151: ROC-AUC: 90.74%. Fairness: R: 79.05%, S: 84.48%, A: 82.28%
# Split 152: ROC-AUC: 82.74%. Fairness: R: 82.60%, S: 93.53%, A: 84.07%
# Split 153: ROC-AUC: 87.51%. Fairness: R: 78.80%, S: 80.67%, A: 77.46%
# Split 154: ROC-AUC: 88.26%. Fairness: R: 74.94%, S: 90.87%, A: 79.29%
# Split 155: ROC-AUC: 90.82%. Fairness: R: 89.04%, S: 86.26%, A: 87.70%
# Split 156: ROC-AUC: 86.84%. Fairness: R: 78.29%, S: 91.69%, A: 77.56%
# Split 157: ROC-AUC: 91.27%. Fairness: R: 93.45%, S: 90.51%, A: 88.13%
# Split 158: ROC-AUC: 88.46%. Fairness: R: 80.19%, S: 90.83%, A: 85.54%
# Split 159: ROC-AUC: 82.60%. Fairness: R: 84.24%, S: 78.00%, A: 91.58%
# Split 160: ROC-AUC: 88.53%. Fairness: R: 86.91%, S: 78.94%, A: 85.90%
# Split 161: ROC-AUC: 90.27%. Fairness: R: 83.88%, S: 81.64%, A: 81.69%
# Split 162: ROC-AUC: 84.90%. Fairness: R: 77.60%, S: 81.71%, A: 82.70%
# Split 163: ROC-AUC: 89.96%. Fairness: R: 88.74%, S: 91.44%, A: 86.20%
# Split 164: ROC-AUC: 89.21%. Fairness: R: 78.73%, S: 75.09%, A: 80.42%
# Split 165: ROC-AUC: 89.82%. Fairness: R: 80.66%, S: 83.47%, A: 80.45%
# Split 166: ROC-AUC: 86.76%. Fairness: R: 79.64%, S: 90.30%, A: 82.67%
# Split 167: ROC-AUC: 86.18%. Fairness: R: 77.59%, S: 90.29%, A: 77.72%
# Split 168: ROC-AUC: 89.23%. Fairness: R: 83.73%, S: 83.85%, A: 85.03%
# Split 169: ROC-AUC: 88.83%. Fairness: R: 80.96%, S: 84.61%, A: 79.22%
# Split 170: ROC-AUC: 89.40%. Fairness: R: 75.23%, S: 90.54%, A: 79.51%
# Split 171: ROC-AUC: 85.58%. Fairness: R: 82.73%, S: 89.88%, A: 84.04%
# Split 172: ROC-AUC: 88.66%. Fairness: R: 78.14%, S: 77.78%, A: 88.48%
# Split 173: ROC-AUC: 87.59%. Fairness: R: 76.40%, S: 87.16%, A: 83.58%
# Split 174: ROC-AUC: 88.87%. Fairness: R: 82.15%, S: 81.35%, A: 87.99%
# Split 175: ROC-AUC: 87.08%. Fairness: R: 77.51%, S: 92.23%, A: 75.40%
# Split 176: ROC-AUC: 89.17%. Fairness: R: 76.40%, S: 74.91%, A: 80.78%
# Split 177: ROC-AUC: 89.57%. Fairness: R: 80.82%, S: 81.18%, A: 94.49%
# Split 178: ROC-AUC: 86.92%. Fairness: R: 84.83%, S: 73.84%, A: 78.01%
# Split 179: ROC-AUC: 88.34%. Fairness: R: 92.01%, S: 82.70%, A: 78.18%
# Split 180: ROC-AUC: 85.55%. Fairness: R: 77.41%, S: 79.66%, A: 72.94%
# Split 181: ROC-AUC: 91.34%. Fairness: R: 82.92%, S: 81.17%, A: 81.21%
# Split 182: ROC-AUC: 89.28%. Fairness: R: 84.47%, S: 79.05%, A: 82.86%
# Split 183: ROC-AUC: 89.07%. Fairness: R: 78.89%, S: 94.42%, A: 84.48%
# Split 184: ROC-AUC: 85.58%. Fairness: R: 86.26%, S: 87.24%, A: 79.28%
# Split 185: ROC-AUC: 87.27%. Fairness: R: 79.60%, S: 78.55%, A: 83.87%
# Split 186: ROC-AUC: 88.77%. Fairness: R: 79.66%, S: 95.09%, A: 93.34%
# Split 187: ROC-AUC: 87.71%. Fairness: R: 77.14%, S: 75.38%, A: 87.38%
# Split 188: ROC-AUC: 90.07%. Fairness: R: 85.36%, S: 86.43%, A: 78.29%
# Split 189: ROC-AUC: 88.18%. Fairness: R: 91.49%, S: 85.05%, A: 84.29%
# Split 190: ROC-AUC: 89.27%. Fairness: R: 79.08%, S: 81.79%, A: 82.97%
# Split 191: ROC-AUC: 84.92%. Fairness: R: 74.40%, S: 76.44%, A: 81.71%
# Split 192: ROC-AUC: 86.06%. Fairness: R: 89.30%, S: 96.14%, A: 78.10%
# Split 193: ROC-AUC: 87.98%. Fairness: R: 77.00%, S: 93.62%, A: 86.06%
# Split 194: ROC-AUC: 87.62%. Fairness: R: 89.43%, S: 80.84%, A: 82.45%
# Split 195: ROC-AUC: 89.02%. Fairness: R: 78.59%, S: 91.94%, A: 70.85%
# Split 196: ROC-AUC: 86.35%. Fairness: R: 87.40%, S: 89.03%, A: 83.78%
# Split 197: ROC-AUC: 86.78%. Fairness: R: 93.84%, S: 78.57%, A: 76.04%
# Split 198: ROC-AUC: 86.48%. Fairness: R: 78.96%, S: 88.57%, A: 80.57%
# Split 199: ROC-AUC: 90.43%. Fairness: R: 81.74%, S: 91.06%, A: 89.68%
# Split 200: ROC-AUC: 88.10%. Fairness: R: 82.05%, S: 76.27%, A: 74.30%
# Split 201: ROC-AUC: 84.66%. Fairness: R: 79.03%, S: 81.77%, A: 77.40%
# Split 202: ROC-AUC: 88.65%. Fairness: R: 89.68%, S: 78.43%, A: 92.38%
# Split 203: ROC-AUC: 87.27%. Fairness: R: 76.85%, S: 92.55%, A: 81.60%
# Split 204: ROC-AUC: 88.90%. Fairness: R: 84.88%, S: 86.70%, A: 73.68%
# Split 205: ROC-AUC: 91.13%. Fairness: R: 78.23%, S: 96.13%, A: 84.01%
# Split 206: ROC-AUC: 87.84%. Fairness: R: 90.07%, S: 79.75%, A: 88.23%
# Split 207: ROC-AUC: 89.74%. Fairness: R: 82.03%, S: 75.25%, A: 83.01%
# Split 208: ROC-AUC: 89.93%. Fairness: R: 80.82%, S: 90.92%, A: 84.71%
# Split 209: ROC-AUC: 85.05%. Fairness: R: 83.79%, S: 93.75%, A: 88.91%
# Split 210: ROC-AUC: 88.04%. Fairness: R: 78.42%, S: 92.11%, A: 75.79%
# Split 211: ROC-AUC: 88.09%. Fairness: R: 76.85%, S: 83.10%, A: 70.75%
# Split 212: ROC-AUC: 85.35%. Fairness: R: 86.95%, S: 86.40%, A: 79.86%
# Split 213: ROC-AUC: 84.95%. Fairness: R: 82.46%, S: 93.04%, A: 82.75%
# Split 214: ROC-AUC: 91.42%. Fairness: R: 91.48%, S: 83.46%, A: 82.52%
# Split 215: ROC-AUC: 87.52%. Fairness: R: 74.27%, S: 83.07%, A: 76.61%
# Split 216: ROC-AUC: 89.81%. Fairness: R: 88.88%, S: 76.00%, A: 88.28%
# Split 217: ROC-AUC: 86.16%. Fairness: R: 80.21%, S: 86.60%, A: 86.48%
# Split 218: ROC-AUC: 89.93%. Fairness: R: 80.82%, S: 99.04%, A: 87.35%
# Split 219: ROC-AUC: 90.37%. Fairness: R: 84.19%, S: 76.81%, A: 92.09%
# Split 220: ROC-AUC: 87.60%. Fairness: R: 82.30%, S: 77.67%, A: 67.37%
# Split 221: ROC-AUC: 85.41%. Fairness: R: 82.55%, S: 92.59%, A: 90.46%
# Split 222: ROC-AUC: 88.58%. Fairness: R: 87.46%, S: 93.30%, A: 91.62%
# Split 223: ROC-AUC: 88.36%. Fairness: R: 81.85%, S: 85.27%, A: 78.21%
# Split 224: ROC-AUC: 89.15%. Fairness: R: 87.02%, S: 91.24%, A: 86.21%
# Split 225: ROC-AUC: 87.96%. Fairness: R: 77.02%, S: 91.30%, A: 84.14%
# Split 226: ROC-AUC: 88.24%. Fairness: R: 76.97%, S: 79.35%, A: 77.41%
# Split 227: ROC-AUC: 85.46%. Fairness: R: 78.92%, S: 73.86%, A: 92.49%
# Split 228: ROC-AUC: 85.67%. Fairness: R: 80.09%, S: 95.06%, A: 96.04%
# Split 229: ROC-AUC: 87.50%. Fairness: R: 87.37%, S: 82.99%, A: 88.20%
# Split 230: ROC-AUC: 90.45%. Fairness: R: 76.77%, S: 99.81%, A: 83.69%
# Split 231: ROC-AUC: 86.98%. Fairness: R: 83.03%, S: 72.91%, A: 82.90%
# Split 232: ROC-AUC: 87.84%. Fairness: R: 79.45%, S: 91.17%, A: 89.59%
# Split 233: ROC-AUC: 90.35%. Fairness: R: 85.84%, S: 85.69%, A: 88.94%
# Split 234: ROC-AUC: 87.21%. Fairness: R: 86.12%, S: 84.28%, A: 74.87%
# Split 235: ROC-AUC: 85.95%. Fairness: R: 80.15%, S: 73.98%, A: 74.78%
# Split 236: ROC-AUC: 89.88%. Fairness: R: 76.78%, S: 80.23%, A: 83.64%
# Split 237: ROC-AUC: 89.73%. Fairness: R: 84.55%, S: 93.97%, A: 89.24%
# Split 238: ROC-AUC: 80.52%. Fairness: R: 80.24%, S: 92.27%, A: 75.35%
# Split 239: ROC-AUC: 87.86%. Fairness: R: 83.34%, S: 74.97%, A: 81.51%
# Split 240: ROC-AUC: 89.31%. Fairness: R: 80.13%, S: 76.94%, A: 87.55%
# Split 241: ROC-AUC: 88.87%. Fairness: R: 89.98%, S: 91.51%, A: 80.27%
# Split 242: ROC-AUC: 88.64%. Fairness: R: 86.96%, S: 88.05%, A: 83.04%
# Split 243: ROC-AUC: 87.19%. Fairness: R: 81.91%, S: 95.69%, A: 80.88%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5c15092f78d5> in <module>
#      49     roc_auc = roc_auc_score(y_eval, preds_proba, multi_class="ovo")
#      50     rm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['race'])
# ---> 51     sm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['sex'])
#      52     am = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['age_group'])
#      53
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\fairlearn\metrics\_metric_frame.py in __init__(self, metric, y_true, y_pred, sensitive_features, control_features, sample_params)
#     149
#     150         self._overall = self._compute_overall(func_dict, y_t, y_p, cf_list)
# --> 151         self._by_group = self._compute_by_group(func_dict, y_t, y_p, sf_list, cf_list)
#     152
#     153     def _compute_overall(self, func_dict, y_true, y_pred, cf_list):
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\fairlearn\metrics\_metric_frame.py in _compute_by_group(self, func_dict, y_true, y_pred, sf_list, cf_list)
#     167             rows = copy.deepcopy(cf_list) + rows
#     168
# --> 169         return self._compute_dataframe_from_rows(func_dict, y_true, y_pred, rows)
#     170
#     171     def _compute_dataframe_from_rows(self, func_dict, y_true, y_pred, rows):
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\fairlearn\metrics\_metric_frame.py in _compute_dataframe_from_rows(self, func_dict, y_true, y_pred, rows)
#     192                 # Only call the metric function if the mask is non-empty
#     193                 if sum(mask) > 0:
# --> 194                     curr_metric = func_dict[func_name].evaluate(y_true, y_pred, mask)
#     195                     result[func_name][row_curr] = curr_metric
#     196         return result
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\fairlearn\metrics\_function_container.py in evaluate(self, y_true, y_pred, mask)
#     101         params = self.generate_sample_params_for_mask(mask)
#     102
# --> 103         return self.func_(y_true[mask], y_pred[mask], **params)
#     104
#     105     def evaluate_all(self,
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     545                                      sample_weight=sample_weight)
#     546     else:  # multilabel-indicator
# --> 547         return _average_binary_score(partial(_binary_roc_auc_score,
#     548                                              max_fpr=max_fpr),
#     549                                      y_true, y_score, average,
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\metrics\_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#     117         y_true_c = y_true.take([c], axis=not_average_axis).ravel()
#     118         y_score_c = y_score.take([c], axis=not_average_axis).ravel()
# --> 119         score[c] = binary_metric(y_true_c, y_score_c,
#     120                                  sample_weight=score_weight)
#     121
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\metrics\_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     325     """Binary roc auc score."""
#     326     if len(np.unique(y_true)) != 2:
# --> 327         raise ValueError("Only one class present in y_true. ROC AUC score "
#     328                          "is not defined in that case.")
#     329
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# Evaluation

race_fairnesses = [(1 - np.sqrt(np.std(rm.by_group))) for rm in rms]
sex_fairnesses = [(1 - np.sqrt(np.std(sm.by_group))) for sm in sms]
age_fairnesses = [(1 - np.sqrt(np.std(am.by_group))) for am in ams]

print(f'ROC-AUC {np.mean(roc_aucs)*100:.2f}% (STD: {np.std(roc_aucs)*100:.2f}%)') # 90.48
print(f'Race fairness: {np.mean(race_fairnesses)*100:.2f}% (STD: {np.std(race_fairnesses)*100:.2f}%)') # 83.92
print(f'Sex fairness: {np.mean(sex_fairnesses)*100:.2f}% (STD: {np.std(sex_fairnesses)*100:.2f}%)')
print(f'Age fairness: {np.mean(age_fairnesses)*100:.2f}% (STD: {np.std(age_fairnesses)*100:.2f}%)')

score = 0.5 * np.mean(roc_aucs) + \
        0.5 * (np.mean([np.mean(race_fairnesses), np.mean(sex_fairnesses), np.mean(age_fairnesses)]))
print(f'Score: {score*100:.2f}%') # 90.48

# %%
#sets cols for oversampled dataset

cols = [
#     'name', useless
#     'first', useless
#     'last', useless
     'sex', # 0 importance + potential bias
#     'date_of_birth', date
     'age', # innapropriate bias
#     'age_group', # innapropriate bias
     'race', # innapropriate bias
    'juv_fel_count',
    'juv_misd_count', 
    'juv_other_count',
    'priors_count', 
    'days_b_screening_arrest',
#     'c_jail_in', date
#     'c_jail_out',date
#     'c_offense_date', date
#     'c_arrest_date', date
#     'c_charge_degree',  # 0 importance
#    'c_charge_desc',
#     'r_jail_in', date
#     'r_jail_out', date
#     'screening_date', date
#     'in_custody', date
#     'out_custody', date
    'start', 
#    'target',# target
#     'target_int', target
#     'target_bool', target
#     'c_bad_date', date
    'custody_days',
    'in_custody_to_screening_days',
#     'birth_to_bad_days', # corr=1 with age
    'has_r_jail_in', 
#     'has_r_jail_out', # corr=1 with r_jail_in
    'days_until_recitivism', # golden feature!
]

cat_cols = [
     'sex',  # innapropriate bias
     'age', # innapropriate bias
     'race' # innapropriate bias
#     'c_charge_degree', # 0 importance
#    'c_charge_desc',
]
#ls = [type(item) for item in cat_cols]
#print(ls)

# %%
#male is 0, female is 1
#df['sex'] = (df['sex'] == 'Female').astype(int)
df.loc[df['sex'] == 'Male', 'sex'] = 0
df.loc[df['sex'] == 'Female', 'sex'] = 1


df.loc[df['race'] == 'Caucasian', 'race'] = 0
df.loc[df['race'] == 'African-American', 'race'] = 1
df.loc[df['race'] == 'Other', 'race'] = 2



df= df.fillna(0)

#races = df.race.unique()
#print(races)

# %% [markdown]
# ## Oversampling

# %%
#creates SMOTE dataset

from collections import Counter
from sklearn.datasets import make_classification
from numpy import where
from imblearn.over_sampling import SMOTE
from matplotlib import pyplot

#df = pd.DataFrame(df, columns=cols)

#X_train, X_test, y_train, y_test = train_test_split(df['Description'],
#    df['Type'], random_state=0)


#define dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, 
      n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

#summarises class distribution
counter = Counter(y)
#Counter({0: 9900, 1: 100}) 
#means 9900 examples in the majority class and 100 in minority class
print(counter)

#transforms dataset
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# target 

df_x_oversampled, df_y_oversampled = oversample.fit_resample(df[cols].round(), df['target_int'])
x_df = pd.DataFrame(df_x_oversampled, columns=cols)
y_df = pd.DataFrame(df_y_oversampled)
dfs_x_y = [x_df, y_df]
df_merged = pd.concat(dfs_x_y)
df_merged= df_merged.fillna(0)
df_merged.sex = df_merged.sex.astype('int')
df_merged.age = df_merged.age.astype('int')
df_merged.race = df_merged.race.astype('int')

#summarises new class distribution
counter = Counter(y)
#Counter({0: 9900, 1: 9900})
#now has 9900 examples in minority class
print(counter)

df_merged.head()
df_merged.dtypes
#y_df.head()
# Out:
# Counter({0: 9900, 1: 100})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e48232429918> in <module>
#      29 # target
#      30
# ---> 31 df_x_oversampled, df_y_oversampled = oversample.fit_resample(df[cols].round(), df['target_int'])
#      32 x_df = pd.DataFrame(df_x_oversampled, columns=cols)
#      33 y_df = pd.DataFrame(df_y_oversampled)
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      73             The corresponding label of `X_resampled`.
#      74         """
# ---> 75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
#      77         X, y, binarize_y = self._check_X_y(X, y)
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     178     y : array-like
#     179     """
# --> 180     y_type = type_of_target(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     301     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     302         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 303         _assert_all_finite(y)
#     304         return 'continuous' + suffix
#     305
#
# c:\users\emmar\documents\projects\caggle\venv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
#SMOTE evaluation
#same code as other evaluation but with SMOTE dataset
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
import collections

kf = RepeatedStratifiedKFold(n_splits=5, n_repeats=10, random_state=42)

# X_train, X_test, y_train, y_test = train_test_split(df[cols], df['target'], test_size=0.2)

avg_precs = []
roc_aucs = []
roc_aucs_race = collections.defaultdict(list)
roc_aucs_age = collections.defaultdict(list)
roc_aucs_sex = collections.defaultdict(list)

#turns race and sex back to what they're supposed to be??
#df_merged.loc[df_merged['sex'] == 0.0, 'sex'] = 'Male'
#df_merged.loc[df_merged['sex'] == 1.0, 'sex'] = 'Female'

#df_merged.loc[df_merged['race'] == 0, 'race'] = 'Caucasian'
#df_merged.loc[df_merged['race'] == 1, 'race'] = 'African-American'
#df_merged.loc[df_merged['race'] == 2, 'race'] = 'Other'


df_merged.head()

# %%
#print(type(df_merged))

feature_importances = []
for split_idx, (train, test) in enumerate(kf.split(df_train[cols], strat_df['name'])): # Stratified on race
    df_train_cv = df.iloc[train].reset_index(drop=True)
    df_eval_cv = df.iloc[test].reset_index(drop=True)
    
    train_dataset = Pool(data=df_train_cv[cols],
                         label=df_train_cv[TARGET_COL],
                         cat_features=cat_cols)

    eval_dataset = Pool(data=df_eval_cv[cols],
                        label=df_eval_cv[TARGET_COL],
                        cat_features=cat_cols)
    
    y_eval = pd.get_dummies(df_eval_cv[TARGET_COL]).to_numpy()
    # Initialize CatBoostClassifier
    model = CatBoostClassifier(iterations=1000,
                               learning_rate=1,
                               depth=3,
                               loss_function='MultiClass')
    # Fit model
    model.fit(train_dataset, verbose=False)
#     # Get predicted probabilities for each class
    preds_proba = model.predict_proba(eval_dataset)
    
    roc_auc = roc_auc_score(y_eval, preds_proba, multi_class="ovo")
    rm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['race'])
    sm = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['sex'])
    am = MetricFrame(roc_auc_score, y_eval, preds_proba, sensitive_features=df_eval_cv['age_group'])
    
    roc_aucs.append(roc_auc)
    rms.append(rm)
    sms.append(sm)
    ams.append(am)
        
    roc_aucs.append(roc_auc)
    feature_importances.append(model.get_feature_importance())
    # avg_precs.append(avg_prec)
    race_fairness = 1 - np.sqrt(np.std(rm.by_group))
    sex_fairness = 1 - np.sqrt(np.std(sm.by_group))
    age_fairness = 1 - np.sqrt(np.std(am.by_group))
    print(f'Split {split_idx+1:2}: ROC-AUC: {roc_auc*100:.2f}%. '
          f'Fairness: R: {race_fairness*100:.2f}%, S: {sex_fairness*100:.2f}%, A: {age_fairness*100:.2f}%')

# %%
race_auc_df = pd.DataFrame({'race': races, 'auc': rm.by_group})
sex_auc_df = pd.DataFrame({'sex': sexes, 'auc': sm.by_group})
age_auc_df = pd.DataFrame({'age': age_groups, 'auc': am.by_group})
                     
display(race_auc_df[race_auc_df['auc'].notna()].plot.barh(x='race'))
display(sex_auc_df[sex_auc_df['auc'].notna()].plot.barh(x='sex'))
display(age_auc_df[age_auc_df['auc'].notna()].plot.barh(x='age'))

# %% [markdown]
# # Full model

# %%
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
import collections
from fairlearn.metrics import MetricFrame

TARGET_COL = 'target'

train_dataset = Pool(data=df_train[cols],
                     label=df_train[TARGET_COL],
                     cat_features=cat_cols)

eval_dataset = Pool(data=df_test[cols],
                    label=None,
                    cat_features=cat_cols)

# y_eval = pd.get_dummies(eval_df[TARGET_COL]).to_numpy()
# Initialize CatBoostClassifier
model = CatBoostClassifier(iterations=100,
                           learning_rate=1,
                           depth=2,
                           loss_function='MultiClass')
# Fit model
model.fit(train_dataset, verbose=True)
# Get predicted classes
preds_class = model.predict(eval_dataset)
#     # Get predicted probabilities for each class
preds_proba = model.predict_proba(eval_dataset)
#     # Get predicted RawFormulaVal
#     preds_raw = model.predict(eval_dataset, 
#                               prediction_type='RawFormulaVal')

feature_importances.append(model.get_feature_importance())

# %%
# Feature importances
fi_df = pd.DataFrame({'feature': cols})
fi_df['importance'] = np.mean(feature_importances, axis=0)
fi_df['std'] = np.std(feature_importances, axis=0)
fi_df['min'] = np.min(feature_importances, axis=0)
fi_df['max'] = np.max(feature_importances, axis=0)
fi_df = fi_df.sort_values('importance', ascending=False)
display(fi_df)
display(fi_df[['feature', 'importance']].sort_values('importance', ascending=True).plot.barh(x='feature'))

# %%
out_cols = ['No-Recidivism', 'Non-Violent', 'Violent']
out_df = pd.DataFrame(preds_proba, columns=out_cols)

# Make sure that classes are in the right order and the highest prediction corresponds to predicted class
out_df['class'] = out_df.apply(lambda x: out_cols[np.argmax(x[out_cols])], axis=1)
assert (out_df['class'] == preds_class.ravel()).all()
out_df = out_df[out_cols]

out_df.to_csv('y_test.csv', index=False)

import urllib.parse
upload_link = urllib.parse.quote('share.streamlit.io/mkleinbort/kaggle-compas/main/app.py')
y_test_link = urllib.parse.quote('y_test.csv')
print(f'Predictions were exported to "y_test.csv". Upload them at https://{upload_link}')
out_df

# %% [markdown]
# # Evaluations log
# ## 30/03/2021 22:18 JK
# ### Columns
# ['days_b_screening_arrest',
#  'start',
#  'custody_days',
#  'in_custody_to_screening_days',
#  'days_until_recitivism',
#  'all_priors']
#
# ### Hyperparams
# ```
# iterations=100,
# learning_rate=1,
# depth=2,
# loss_function='MultiClass'
# ```
#
# ## Results
# ### CV
# ```
# ROC-AUC 87.67% (STD: 1.96%)
# Race fairness: 82.86% (STD: 4.02%)
# Sex fairness: 84.82% (STD: 6.47%)
# Age fairness: 81.86% (STD: 4.66%)
# Score: 85.42%
# ```
#
# ### Online
# ```
# {
#   "accuracy": 0.8442265121761089,
#   "fairness": 0.606948047720613
# }
# Overall Score: 72.56%
# ```

# %%
# {
#   "accuracy": 0.8421805473187943,
#   "fairness": 0.6626350268234771
# }

# 75.24%
